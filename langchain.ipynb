# %%
from langchain.llms import Ollama


llm = Ollama(model="mistral")
llm("The first man on the moon was ...")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/user/vladimir/SAIRA/langchain.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22414553227d/home/user/vladimir/SAIRA/langchain.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> from langchain.llms import Ollama
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22414553227d/home/user/vladimir/SAIRA/langchain.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> llm = Ollama(model="mistral")
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22414553227d/home/user/vladimir/SAIRA/langchain.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> llm("The first man on the moon was ...")
#
# File /usr/local/lib/python3.8/dist-packages/langchain/__init__.py:6
#       3 from importlib import metadata
#       4 from typing import Optional
# ...
