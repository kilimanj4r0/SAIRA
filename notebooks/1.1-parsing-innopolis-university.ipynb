# %% [markdown]
# ## 1. Parsing using mistune

# %%
import os
import re
import time
import requests
import mistune
from bs4 import BeautifulSoup


# Custom renderer to treat HTML tags as plain text
class MyRenderer(mistune.Renderer):
    def text(self, text):
        return text

    def paragraph(self, text):
        return text + '\n\n'

    def block_code(self, code, lang=None):
        return '\n\n```\n{}\n```\n\n'.format(code)

    def block_quote(self, text):
        return '> {}\n\n'.format(text)

    def header(self, text, level, raw=None):
        return '{} {}\n\n'.format('#' * level, text)

    def list(self, body, ordered=True):
        return '{}\n\n'.format(body)

    def list_item(self, text):
        return '- {}\n'.format(text)

    def double_emphasis(self, text):
        return '**{}**'.format(text)

    def emphasis(self, text):
        return '*{}*'.format(text)

    def strikethrough(self, text):
        return '~~{}~~'.format(text)

    def linebreak(self):
        return '\n'

def clean_text(text):
    # Remove excessive line breaks and carriage returns
    cleaned_text = re.sub(r'[\r\n]+', '\n', text)
    cleaned_text = re.sub(r' +', ' ', text)
    cleaned_text = re.sub(r'^( +)', '', text, flags=re.MULTILINE)
    return cleaned_text

def parse_page(url):
    visited.add(url)
    print(f"Parsing page: {url}")

    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    # Extract text content and clean it
    text_content = soup.get_text()
    cleaned_content = clean_text(text_content)

    # Configure mistune with custom renderer
    markdown = mistune.Markdown(renderer=MyRenderer())

    # Convert cleaned text content to Markdown
    markdown_content = markdown(cleaned_content)

    # Save Markdown content to a file
    filename = url.replace('https://', '').replace('/', '_') + '.md'
    with open(filename, 'w', encoding='utf-8') as file:
        file.write(markdown_content)
        print(f"Markdown content saved to: {filename}")

    # Find links on the page and process them
    links = set()
    for link in soup.find_all('a', href=True):
        link_href = link.get('href')
        links.add(link_href)

        if (link_href.startswith('http') 
                and link_href not in visited
                and depth_dict.get(link_href, 0) < max_depth):
            queue.append(link_href)
            depth_dict[link_href] = depth_dict.get(url, 0) + 1

visited = set()
queue = ['https://innopolis.university/']
depth_dict = {'https://innopolis.university/': 0}
max_depth = 3

while queue:
    current_url = queue.pop(0)
    if current_url not in visited:
        parse_page(current_url)

# %%
# !cat innopolis.university_.md

# %% [markdown]
# ## 2. Parsing using readability

# %% [markdown]
# ### 2.1 Parsing

# %%
# !pip install readability-lxml

# %%
from bs4 import BeautifulSoup

def extract_links_exclude_domains(html_content, base_url, excluded_domains):
    """
    Extract links from a webpage excluding specified domains.
    """
    soup = BeautifulSoup(html_content, 'html.parser')
    links = [link.get('href') for link in soup.find_all('a', href=True)]
    
    is_included = lambda x: not any(domain in x for domain in excluded_domains)
    is_innopolis = lambda x: 'innopolis' in x
    
    absolute_links = [urljoin(base_url, link) for link in links if is_included(link) and is_innopolis(link)]
    return absolute_links

# %%
import re
from readability import Document

def extract_summary(html_content):
    response = requests.get(html_content)
    doc = Document(response.content)
    soup = BeautifulSoup(doc.summary())
    summary = "\n".join([paragraph.strip() for paragraph in re.split("\n", soup.text) if len(paragraph)])
    return summary

# %%
import os
import requests
from urllib.parse import urljoin

def crawl_webpage_exclude_domains(url, depth=0, max_depth=3, visited=None, excluded_domains=None):
    if visited is None:
        visited = set()
    if excluded_domains is None:
        excluded_domains = ['t.me', 'telegram.org', 'vk.com', 'youtube.com']

    try:
        if url in visited:
            return
        
        visited.add(url)
        print(f"Processing depth {depth}: {url}")
        
        response = requests.get(url)

        # Save content to a text file
        filename = url.split('//')[1]
        filename = filename[:-1] if filename.endswith('/') else filename
        filename = filename.replace('/', '_').replace(':', '_') + ".txt"
        with open(filename, 'w', encoding='utf-8') as file:
            file.write(extract_summary(url))

        # Extract links from the webpage excluding specified domains
        if depth < max_depth:
            links = extract_links_exclude_domains(response.content, url, excluded_domains)
            for link in links:
                crawl_webpage_exclude_domains(link, depth + 1, max_depth, visited, excluded_domains)
    except Exception as e:
        print(f"Error occurred: {e}")

# %%
starting_url = 'https://innopolis.university'

if not os.path.exists('webpage_content'):
    os.makedirs('webpage_content')

os.chdir('webpage_content')

try:
    crawl_webpage_exclude_domains(starting_url, max_depth=1)
finally:
    os.chdir('..')

# %% [markdown]
# ### 2.2 Examples

# %%
print(extract_summary('https://apply.innopolis.university/faq/'))

# %%
print(extract_summary('https://apply.innopolis.university/grant/'))

# %%
print(extract_summary('https://media.innopolis.university/news/World-Science-Day/'))

# %%
# !tar -czvf innopolis.university.tar.gz webpage_content
# Out:
# webpage_content/
# webpage_content/itbm.innopolis.university_?utm_source=innopolis_glavnaya#rec469478443.txt
# webpage_content/innopolis.university_portfel-proektov.txt
# webpage_content/media.innopolis.university_news_iu-ai-journey-science-2023.txt
# webpage_content/my.university.innopolis.ru.txt
# webpage_content/apply.innopolis.university_master.txt
# webpage_content/stc.innopolis.university.txt
# webpage_content/innopolis.university_center-cybersecurity.txt
# webpage_content/stc.innopolis.university_codeschool.txt
# webpage_content/dovuz.innopolis.university_training.txt
# webpage_content/media.innopolis.university_news_All-Russian-AI-Olympiad-Results.txt
# webpage_content/dovuz.innopolis.university_login.txt
# webpage_content/it.university.innopolis.ru_otrs_customer.pl.txt
# webpage_content/media.innopolis.university.txt
# webpage_content/innopolis.university_search.txt
# webpage_content/innopolis.university_sveden.txt
# webpage_content/apply.innopolis.university_bachelor.txt
# webpage_content/apply.innopolis.university_?lang=ru&id=12&site=s1&template=university24&landing_mode=edit.txt
# webpage_content/media.innopolis.university_events_?lang=ru&id=12&site=s1&template=university24&landing_mode=edit.txt
# webpage_content/innopolis.university_dpo-courses.txt
# webpage_content/iustore.innopolis.ru.txt
# webpage_content/apply.innopolis.university_stazhirovki-i-trudoustrojstvo.txt
# webpage_content/apply.innopolis.university_open-day.txt
# webpage_content/stc.innopolis.university_careerinit.txt
# webpage_content/innopolis.university_ooc.txt
# webpage_content/innopolis.university_center-blockchain.txt
# webpage_content/innopolis.university_nir2022.txt
# webpage_content/innopolis.university_team.txt
# webpage_content/dovuz.innopolis.university_about.txt
# webpage_content/career.innopolis.university_relocation.txt
# webpage_content/corporate.innopolis.university_education.txt
# webpage_content/innopolis.university_proekty_consulting.txt
# webpage_content/innopolis.university_form.txt
# webpage_content/edu.innopolis.university_ooc.txt
# webpage_content/career.innopolis.university.txt
# webpage_content/team-project.university.innopolis.ru_partnership.txt
# webpage_content/media.innopolis.university_news_digital-education-2023.txt
# webpage_content/media.innopolis.university_?lang=ru&id=12&site=s1&template=university24&landing_mode=edit.txt
# webpage_content/innopolis.university_center-oil.txt
# webpage_content/innopolis.university_publikatsii.txt
# webpage_content/dovuz.innopolis.university_olympics.txt
# webpage_content/innopolis.university_international-relations-office.txt
# webpage_content/innopolis.university_integration-bee.txt
# webpage_content/innopolis.university_seminars.txt
# webpage_content/portal.university.innopolis.ru.txt
# webpage_content/progmatica.innopolis.university.txt
# webpage_content/innopolis.university_campus.txt
# webpage_content/media.innopolis.university_news_way-to-the-olymp-2023.txt
# webpage_content/innopolis.university_antiterror_?lang=ru&id=12&site=s1&template=university24&landing_mode=edit.txt
# webpage_content/innopolis.university_faculty.txt
# webpage_content/innopolis.university_lk.txt
# webpage_content/innopolis.university_assessment-center.txt
# webpage_content/iustore.innopolis.ru_?lang=ru&id=12&site=s1&template=university24&landing_mode=edit.txt
# webpage_content/apply.innopolis.university_stud-life.txt
# webpage_content/innopolis.university_center-ai3.txt
# webpage_content/apply.innopolis.university_grant.txt
# webpage_content/career.innopolis.university_konkursnyezayavkiprofessorskoprepodavatelskogosostava.txt
# webpage_content/media.innopolis.university_news_World-Science-Day.txt
# webpage_content/www.innopolis.com_city_how-to-get_?lang=ru&id=12&site=s1&template=university24&landing_mode=edit.txt
# webpage_content/mail.innopolis.ru_owa_auth_logon.aspx?replaceCurrent=1&url=https%3a%2f%2fmail.innopolis.ru%2fowa%2f.txt
# webpage_content/innopolis.university_ppcenter.txt
# webpage_content/innopolis.university_center-municipal-services.txt
# webpage_content/innopolis.university_sponsorship.txt
# webpage_content/media.innopolis.university_news_veha-2023-iu.txt
# webpage_content/itbm.innopolis.university.txt
# webpage_content/stc.innopolis.university_webinars?utm_source=innopolis_glavnaya.txt
# webpage_content/apply.innopolis.university_olympiad-bonus.txt
# webpage_content/dovuz.innopolis.university.txt
# webpage_content/dovuz.innopolis.university_events.txt
# webpage_content/innopolis.university_team-structure_team-faculty.txt
# webpage_content/career.innopolis.university_job?lang=ru&id=12&site=s1&template=university24&landing_mode=edit.txt
# webpage_content/career.innopolis.university_job.txt
# webpage_content/stc.innopolis.university_?utm_source=innopolis_glavnaya.txt
# webpage_content/innopolis.university.txt
# webpage_content/apply.innopolis.ru_get-in.txt
# webpage_content/innopolis.university_board.txt
# webpage_content/innopolis.university_startupstudio.txt
# webpage_content/apply.innopolis.university.txt
# webpage_content/apply.innopolis.university_olymp-math.txt
# webpage_content/events.innopolis.university_startuphouse.txt
# webpage_content/apply.innopolis.university_postgraduate-study.txt
# webpage_content/innopolis.university_files_politicacookies.pdf?lang=ru&id=12&site=s1&template=university24&landing_mode=edit.txt
# webpage_content/alumni.innopolis.university.txt
# webpage_content/innopolis.university_engineering-school.txt
# webpage_content/innopolis.university_assessment-center?utm_source=innopolis_glavnaya.txt
# webpage_content/innopolis.university_ido.txt
# webpage_content/innopolis.university_science.txt
# webpage_content/innopolis.university_sveden_?lang=ru&id=12&site=s1&template=university24&landing_mode=edit.txt
# webpage_content/innopolis.university_organizatsiya-i-provedenie-meropriyatiy.txt
# webpage_content/innopolis.university_center-energy.txt
# webpage_content/innopolis.university_about.txt
# webpage_content/innopolis.university_technologytransfercenter.txt
# webpage_content/innopolis.university_team-structure_education-academics.txt
# webpage_content/trud.innopolis.university_?utm_source=innopolis_glavnaya.txt
# webpage_content/msonline.innopolis.university.txt
# webpage_content/innopolis.university_centergis.txt
# webpage_content/innopolis.university_team-structure.txt
# webpage_content/innopolis.university_bitrix_admin_landing_view.php?lang=ru&id=12&site=s1&template=university24&landing_mode=edit#landing151?lang=ru&id=12&site=s1&template=university24&landing_mode=edit.txt
# webpage_content/innopolis.university_team-structure_team-faculty2.txt
# webpage_content/apply.innopolis.university_faq.txt
# webpage_content/innopolis.university_contacts.txt
# webpage_content/edu.innopolis.university_cdto?utm_source=innopolis_glavnaya.txt
# webpage_content/career.innopolis.university_en_job.txt
# webpage_content/dovuz.innopolis.university_regular.txt
# webpage_content/innopolis.university_team-structure_techcenters.txt
# webpage_content/innopolis.university_sveden_apply.txt
# webpage_content/innopolis.university_center-robotics.txt
# webpage_content/media.innopolis.university_news_innoctf-junior-2023-autumn.txt
# webpage_content/innopolis.university_proekty_activity.txt
# webpage_content/dovuz.innopolis.university_ege.txt
