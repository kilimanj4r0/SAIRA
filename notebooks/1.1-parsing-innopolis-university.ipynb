# %% [markdown]
# ## 1. Parsing using mistune

# %%
import os
import re
import time
import requests
import mistune
from bs4 import BeautifulSoup


# Custom renderer to treat HTML tags as plain text
class MyRenderer(mistune.Renderer):
    def text(self, text):
        return text

    def paragraph(self, text):
        return text + '\n\n'

    def block_code(self, code, lang=None):
        return '\n\n```\n{}\n```\n\n'.format(code)

    def block_quote(self, text):
        return '> {}\n\n'.format(text)

    def header(self, text, level, raw=None):
        return '{} {}\n\n'.format('#' * level, text)

    def list(self, body, ordered=True):
        return '{}\n\n'.format(body)

    def list_item(self, text):
        return '- {}\n'.format(text)

    def double_emphasis(self, text):
        return '**{}**'.format(text)

    def emphasis(self, text):
        return '*{}*'.format(text)

    def strikethrough(self, text):
        return '~~{}~~'.format(text)

    def linebreak(self):
        return '\n'

def clean_text(text):
    # Remove excessive line breaks and carriage returns
    cleaned_text = re.sub(r'[\r\n]+', '\n', text)
    cleaned_text = re.sub(r' +', ' ', text)
    cleaned_text = re.sub(r'^( +)', '', text, flags=re.MULTILINE)
    return cleaned_text

def parse_page(url):
    visited.add(url)
    print(f"Parsing page: {url}")

    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    # Extract text content and clean it
    text_content = soup.get_text()
    cleaned_content = clean_text(text_content)

    # Configure mistune with custom renderer
    markdown = mistune.Markdown(renderer=MyRenderer())

    # Convert cleaned text content to Markdown
    markdown_content = markdown(cleaned_content)

    # Save Markdown content to a file
    filename = url.replace('https://', '').replace('/', '_') + '.md'
    with open(filename, 'w', encoding='utf-8') as file:
        file.write(markdown_content)
        print(f"Markdown content saved to: {filename}")

    # Find links on the page and process them
    links = set()
    for link in soup.find_all('a', href=True):
        link_href = link.get('href')
        links.add(link_href)

        if (link_href.startswith('http') 
                and link_href not in visited
                and depth_dict.get(link_href, 0) < max_depth):
            queue.append(link_href)
            depth_dict[link_href] = depth_dict.get(url, 0) + 1

visited = set()
queue = ['https://innopolis.university/']
depth_dict = {'https://innopolis.university/': 0}
max_depth = 3

while queue:
    current_url = queue.pop(0)
    if current_url not in visited:
        parse_page(current_url)

# %%
# !cat innopolis.university_.md

# %% [markdown]
# ## 2. Parsing using readability

# %% [markdown]
# ### 2.1 Parsing

# %%
# !pip install readability-lxml

# %%
from bs4 import BeautifulSoup

def extract_links_exclude_domains(html_content, base_url, excluded_domains):
    """
    Extract links from a webpage excluding specified domains.
    """
    soup = BeautifulSoup(html_content, 'html.parser')
    links = [link.get('href') for link in soup.find_all('a', href=True)]
    
    is_included = lambda x: not any(domain in x for domain in excluded_domains)
    is_innopolis = lambda x: 'innopolis' in x
    
    absolute_links = [urljoin(base_url, link) for link in links if is_included(link) and is_innopolis(link)]
    return absolute_links

# %%
import re
from readability import Document

def extract_summary(html_content):
    response = requests.get(html_content)
    doc = Document(response.content)
    soup = BeautifulSoup(doc.summary())
    summary = "\n".join([paragraph.strip() for paragraph in re.split("\n", soup.text) if len(paragraph)])
    return summary

# %%
import os
import requests
from urllib.parse import urljoin

def crawl_webpage_exclude_domains(url, depth=0, max_depth=3, visited=None, excluded_domains=None):
    if visited is None:
        visited = set()
    if excluded_domains is None:
        excluded_domains = ['t.me', 'telegram.org', 'vk.com', 'youtube.com']

    try:
        if url in visited:
            return
        
        visited.add(url)
        print(f"Processing depth {depth}: {url}")
        
        response = requests.get(url)

        # Save content to a text file
        filename = f"{url.replace('/', '_').replace(':', '_')}.txt"
        with open(filename, 'w', encoding='utf-8') as file:
            file.write(extract_readability_summary(url))

        # Extract links from the webpage excluding specified domains
        if depth < max_depth:
            links = extract_links_exclude_domains(response.content, url, excluded_domains)
            for link in links:
                crawl_webpage_exclude_domains(link, depth + 1, max_depth, visited, excluded_domains)
    except Exception as e:
        print(f"Error occurred: {e}")

# %%
starting_url = 'https://innopolis.university/'

if not os.path.exists('webpage_content'):
    os.makedirs('webpage_content')

os.chdir('webpage_content')

try:
    crawl_webpage_exclude_domains(starting_url, max_depth=1)
finally:
    os.chdir('..')
# Out:
# Processing depth 0: https://innopolis.university/
# Processing depth 1: https://innopolis.university/about/
# Processing depth 1: https://innopolis.university/board/
# Processing depth 1: https://innopolis.university/team/
# Processing depth 1: https://innopolis.university/team-structure/
# Processing depth 1: https://innopolis.university/team-structure/education-academics/
# Processing depth 1: https://innopolis.university/team-structure/techcenters/
# Processing depth 1: https://innopolis.university/faculty/
# Processing depth 1: https://career.innopolis.university/en/job/
# Processing depth 1: https://career.innopolis.university
# Processing depth 1: https://career.innopolis.university/job
# Processing depth 1: https://career.innopolis.university/relocation/
# Processing depth 1: https://innopolis.university/campus
# Processing depth 1: https://innopolis.university/sveden/
# Processing depth 1: http://iustore.innopolis.ru
# Processing depth 1: https://apply.innopolis.university/
# Processing depth 1: https://innopolis.university/sveden/apply/
# Processing depth 1: https://apply.innopolis.university/open-day/
# Processing depth 1: https://apply.innopolis.university/grant/
# Processing depth 1: https://apply.innopolis.university/olympiad-bonus/
# Processing depth 1: https://apply.innopolis.university/faq/
# Processing depth 1: https://apply.innopolis.university/bachelor/
# Processing depth 1: https://apply.innopolis.university/master/
# Processing depth 1: https://msonline.innopolis.university/
# Processing depth 1: https://apply.innopolis.university/postgraduate-study/
# Processing depth 1: https://dovuz.innopolis.university/
# Processing depth 1: https://dovuz.innopolis.university/about/
# Processing depth 1: https://dovuz.innopolis.university/ege
# Processing depth 1: https://dovuz.innopolis.university/training/
# Processing depth 1: https://dovuz.innopolis.university/regular/
# Processing depth 1: https://dovuz.innopolis.university/olympics/
# Processing depth 1: https://dovuz.innopolis.university/events/
# Processing depth 1: https://team-project.university.innopolis.ru/partnership
# Processing depth 1: https://innopolis.university/dpo-courses/
# Processing depth 1: https://stc.innopolis.university/
# Processing depth 1: https://corporate.innopolis.university/education/
# Processing depth 1: https://edu.innopolis.university/ooc
# Processing depth 1: https://stc.innopolis.university/careerinit
# Processing depth 1: https://innopolis.university/ooc/
# Processing depth 1: https://innopolis.university/ido/
# Processing depth 1: https://innopolis.university/ppcenter/
# Processing depth 1: https://apply.innopolis.university/stazhirovki-i-trudoustrojstvo/
# Processing depth 1: https://apply.innopolis.university/stud-life/
# Processing depth 1: https://apply.innopolis.university/olymp-math/
# Processing depth 1: https://innopolis.university/integration-bee/
# Processing depth 1: https://alumni.innopolis.university/
# Processing depth 1: https://innopolis.university/science
# Processing depth 1: https://innopolis.university/team-structure/team-faculty/
# Processing depth 1: https://innopolis.university/team-structure/team-faculty2/
# Processing depth 1: https://innopolis.university/publikatsii
# Processing depth 1: https://innopolis.university/international-relations-office/
# Processing depth 1: https://innopolis.university/seminars/
# Processing depth 1: https://innopolis.university/nir2022/
# Processing depth 1: https://innopolis.university/proekty/activity/
# Processing depth 1: https://innopolis.university/portfel-proektov/
# Processing depth 1: https://innopolis.university/center-ai3/
# Processing depth 1: https://innopolis.university/center-blockchain/
# Processing depth 1: https://innopolis.university/centergis/
# Processing depth 1: https://innopolis.university/center-municipal-services/
# Processing depth 1: https://innopolis.university/center-cybersecurity/
# Processing depth 1: https://innopolis.university/center-oil/
# Processing depth 1: https://innopolis.university/center-robotics/
# Processing depth 1: https://innopolis.university/center-energy/
# Processing depth 1: https://innopolis.university/proekty/consulting/
# Processing depth 1: https://innopolis.university/startupstudio/
# Processing depth 1: https://events.innopolis.university/startuphouse
# Processing depth 1: https://innopolis.university/technologytransfercenter
# Processing depth 1: https://innopolis.university/engineering-school/
# Processing depth 1: https://innopolis.university/organizatsiya-i-provedenie-meropriyatiy/
# Processing depth 1: https://innopolis.university/sponsorship/
# Processing depth 1: https://innopolis.university/contacts/
# Processing depth 1: https://my.university.innopolis.ru/
# Processing depth 1: https://mail.innopolis.ru/owa/auth/logon.aspx?replaceCurrent=1&url=https%3a%2f%2fmail.innopolis.ru%2fowa%2f
# Processing depth 1: https://portal.university.innopolis.ru/
# Processing depth 1: https://apply.innopolis.ru/get-in/
# Processing depth 1: https://dovuz.innopolis.university/login/
# Processing depth 1: https://it.university.innopolis.ru/otrs/customer.pl
# Processing depth 1: mailto:it@innopolis.ru
# Error occurred: No connection adapters were found for 'mailto:it@innopolis.ru'
# Processing depth 1: https://innopolis.university/search/
# Processing depth 1: https://innopolis.university/lk/
# Processing depth 1: https://career.innopolis.university/
# Processing depth 1: http://dovuz.innopolis.university/
# Processing depth 1: https://progmatica.innopolis.university/
# Processing depth 1: https://stc.innopolis.university/codeschool
# Processing depth 1: https://stc.innopolis.university/webinars?utm_source=innopolis_glavnaya
# Processing depth 1: https://trud.innopolis.university/?utm_source=innopolis_glavnaya
# Processing depth 1: https://stc.innopolis.university/?utm_source=innopolis_glavnaya
# Processing depth 1: https://innopolis.university/assessment-center?utm_source=innopolis_glavnaya
# Processing depth 1: https://itbm.innopolis.university/
# Processing depth 1: https://edu.innopolis.university/cdto?utm_source=innopolis_glavnaya
# Processing depth 1: https://itbm.innopolis.university/?utm_source=innopolis_glavnaya#rec469478443
# Processing depth 1: https://innopolis.university/assessment-center/
# Processing depth 1: https://media.innopolis.university/news/World-Science-Day/
# Processing depth 1: https://media.innopolis.university/news/All-Russian-AI-Olympiad-Results/
# Processing depth 1: https://media.innopolis.university/news/innoctf-junior-2023-autumn/
# Processing depth 1: https://media.innopolis.university/news/way-to-the-olymp-2023/
# Processing depth 1: https://media.innopolis.university/news/veha-2023-iu/
# Processing depth 1: https://media.innopolis.university/news/digital-education-2023/
# Processing depth 1: https://media.innopolis.university/news/expanding-cooperation-on-robotization-with-Gazprom-VNIIGAZ/
# Processing depth 1: https://media.innopolis.university/
# Processing depth 1: mailto:university@innopolis.ru
# Error occurred: No connection adapters were found for 'mailto:university@innopolis.ru'
# Processing depth 1: https://innopolis.university/form/
# Processing depth 1: https://apply.innopolis.university/?lang=ru&id=12&site=s1&template=university24&landing_mode=edit
# Processing depth 1: https://career.innopolis.university/job?lang=ru&id=12&site=s1&template=university24&landing_mode=edit
# Processing depth 1: http://iustore.innopolis.ru/?lang=ru&id=12&site=s1&template=university24&landing_mode=edit
# Processing depth 1: mailto:university@innopolis.ru?lang=ru&id=12&site=s1&template=university24&landing_mode=edit
# Error occurred: No connection adapters were found for 'mailto:university@innopolis.ru?lang=ru&id=12&site=s1&template=university24&landing_mode=edit'
# Processing depth 1: https://innopolis.university/bitrix/admin/landing_view.php?lang=ru&id=12&site=s1&template=university24&landing_mode=edit#landing151?lang=ru&id=12&site=s1&template=university24&landing_mode=edit
# Processing depth 1: http://www.innopolis.com/city/how-to-get/?lang=ru&id=12&site=s1&template=university24&landing_mode=edit
# Processing depth 1: mailto:319@innopolis.ru?lang=ru&id=12&site=s1&template=university24&landing_mode=edit
# Error occurred: No connection adapters were found for 'mailto:319@innopolis.ru?lang=ru&id=12&site=s1&template=university24&landing_mode=edit'
# Processing depth 1: mailto:pr@innopolis.ru?lang=ru&id=12&site=s1&template=university24&landing_mode=edit
# Error occurred: No connection adapters were found for 'mailto:pr@innopolis.ru?lang=ru&id=12&site=s1&template=university24&landing_mode=edit'
# Processing depth 1: https://media.innopolis.university/?lang=ru&id=12&site=s1&template=university24&landing_mode=edit
# Processing depth 1: https://media.innopolis.university/events/?lang=ru&id=12&site=s1&template=university24&landing_mode=edit
# Processing depth 1: https://innopolis.university/sveden/?lang=ru&id=12&site=s1&template=university24&landing_mode=edit
# Processing depth 1: https://career.innopolis.university/konkursnyezayavkiprofessorskoprepodavatelskogosostava/
# Processing depth 1: https://innopolis.university/files/politicacookies.pdf?lang=ru&id=12&site=s1&template=university24&landing_mode=edit
# Processing depth 1: https://innopolis.university/antiterror/?lang=ru&id=12&site=s1&template=university24&landing_mode=edit

# %% [markdown]
# ### 2.2 Examples

# %%
print(extract_readability_summary('https://apply.innopolis.university/faq/'))
# Out:
# В качестве абитуриентов на бакалавриат мы ожидаем как граждан России, так и представителей зарубежных стран.
# Граждане РФ:
# — выпускники школ, завершающие обучение в 11 классе;
# — выпускники колледжей с дипломами о среднем профессиональном образовании*;
# — студенты выпускных классов колледжей ИТ-специальностей.
# Граждане стран СНГ, поступающие в университет, также должны принадлежать к одной из вышеуказанных категорий. Сдавать ЕГЭ этим абитуриентам не требуется, они будут зачислены по результатам грантового конкурса и внутренних вступительных испытаний Университета Иннополис.
# *Эта категория выпускников зачисляется при наличии выигранного гранта, диплома и действующих баллах ЕГЭ/по результатам внутренних вступительных испытаний Университета Иннополис.

# %%
print(extract_readability_summary('https://apply.innopolis.university/grant/'))
# Out:
# Первый шаг одинаков для всех – нужно зарегистрировать заявку (она же – личный кабинет абитуриента) на apply.innopolis.ru.
# Главное - сделать это в нужный момент. Помимо заполнения анкеты, понадобится пройти проверку на уровень знания английского языка и IT-навыков.
#
# Если результат рассмотрения заявки положительный, абитуриент приглашается на второй тур отборов.
#
# В программе: оценка IT-навыков и знания английского языка, собеседование с профессорами на английском языке, оценка личностных качеств.
#
# При успешном прохождении второго тура отборов будущий студент получает грант на обучение.

# %%
print(extract_readability_summary('https://media.innopolis.university/news/World-Science-Day/'))
# Out:
# Дмитрий Менделеев мастерил чемоданы, Никола Тесла любил голубей, Альберт Эйнштейн играл на скрипке, Лев Ландау увлекался кино, а Пьер и Мария Кюри путешествовали на велосипедах. Во Всемирный день науки сотрудники российского ИТ-вуза поделились мыслями о том, как их хобби помогают исследовательской работе и наоборот.
# Валерия Скворцова, лаборант Центра технологий компонентов робототехники и мехатроники Университета Иннополис, преподаватель
#
# В Университете Иннополис я занимаюсь разработкой экзоскелетов и реабилитационных девайсов. В целом, мне интересно создать новые приборы, оптимизировать дизайны под разные задачи и использовать робототехнику для восстановления или усиления моторных функций человека. Например, мои проекты — это робот для реабилитации кисти руки после инсульта и экзоскелет на базе приводов на скручивающихся нитях для компенсации усилий в теле человека при поднятии тяжестей с пола.
#
# А после работы над роботами-манипуляторами и преподавания физики и мехатроники студентам я участвую в стендап-концертах со своими монологами. В комедию попала просто: очень хотелось привлечь внимание руководителя стендап-клуба Иннополиса. Получилось. Попутно оказалось, что мне нравится «обшучивать» многие жизненные ситуации, что стендап для меня — это бесплатная психотерапия. О науке я пока не шучу — сложно сделать такой юмор понятным и «незадротским», но, чувствую, что после получения кандидатской степени шуток про диссертацию в моих монологах будет достаточно. Более того, с комиками из городского стендап-клуба приятно проводить время и придумывать что-то новое — у нас получилось супер-крутое коммьюнити, завязанное на детских травмах. Стендап в Иннополисе — детище моего молодого человека, и меня вдохновляет то, во что вырос клуб под его руководством.
# Мунир Махмутов, старший преподаватель Факультета компьютерных и инженерных наук Университета Иннополис
#
# Исследования становятся логичным продолжением моей преподавательской деятельности в университете. Во время стажировок со студентами у нас возникают идеи для научных работ. Чаще всего темы оказываются связаны с генерацией и транскрипцией музыки — сферами моих научных интересов. Генерация музыки может значительно сокращать расходы на работу композиторов во время подготовки фильма, а в определённых случаях — использоваться как киллер-фича, например, в видеоиграх. Транскрипция музыки ускоряет для исполнителей процесс переноса музыкальных идей в нотную грамоту, что тоже очень полезно.
#
# Помимо преподавания и исследований я пишу тексты и музыку и выступаю в рок-группе Acid Venom. Идея создать собственную группу пришла ещё в школьные годы, в 2013 году начали делать первые серьёзные шаги, в команде появились новые участники. Начинали мы в жанре альтернативного рока и со временем «утяжелились» до хэви-метала, а позднее даже до прогрессив-метала. Нынешним жанром нашей музыки скорее является альтернативный метал. Уже выпустили два полноформатных альбома, послушать можно на популярных стриминговых сервисах. Скоро ожидается также выход мини-альбома из 4 композиций.
#
# Мои занятия наукой и музыкой связаны — одно является вдохновением для другого и наоборот. Также это позволяет мне не замыкаться на одной сфере, а это важно для исследователя. Научная работа о музыке и преподавание позволяют открывать ранее неочевидные вещи, которые потом в какой-то форме попадают в новые рок-композиции. Точно так же хобби подсказывает идеи, которые можно было бы использовать в исследованиях. К примеру, моё желание ускорить преобразование музыкальных идей в нотную грамоту переросло в научную работу по автоматической транскрипции музыки.
# Илья Першин, ведущий инженер-исследователь Лаборатории искусственного интеллекта в медицине Университета Иннополис
#
# Анализ взгляда рентгенолога — моё основное направление исследований. Медицинская визуализация является ключевым инструментом в рентгенологии. Человек воспринимает визуальную информацию глазами, поэтому взаимодействие рентгенолога с системой медицинской визуализации более естественно на основе взгляда, чем используя клики мышью и нажатия клавиш на клавиатуре. Один из проектов, которым сейчас занимаюсь в Университете Иннополис, связан с автоматическим выделением области органов на объёмных медицинских изображениях. Ручная разметка органов или даже исправление существующей является кропотливой работой, так как изображения состоят из большого количества срезов. Оказалось, что это можно делать эффективнее, анализируя направление взгляда и внося изменения в сегментацию в режиме реального времени.
#
# В свободное от исследований время мы с другом делали шахматы из книг о Гарри Поттере, где фигуры перемещаются на доске самостоятельно. Этот проект возник в школьные годы и воплотил мечту о волшебстве в нашем мире. К сожалению, у меня нет времени заниматься им сейчас, но я всегда с теплом вспоминаю те моменты, когда приходилось решать задачи, которыми до этого никогда не занимался: от проектирования системы передвижения фигур и печатных плат до пайки и выпиливания деталей для корпуса шахматной доски. Мы завершили техническую часть, но не успели изготовить красивый корпус. Мой друг разработал реалистичную визуализацию того, к чему мы стремились.
#
# Достижения науки позволили решать задачи, которые ранее являлись прерогативой человека. Сегодня в медицине это позволяет автоматически анализировать информацию о пациенте, оптимизировать рабочие процессы врачей и повышать качество медицинской диагностики. На мой взгляд, учёные в каком-то смысле являются волшебниками.
# Дмитрий Павлов, инженер-исследователь Центра беспилотных технологий Университета Иннополис
#
# Меня интересуют любые транспортные средства и их производства. В Университете Иннополис я занимаюсь разработкой технологий изготовления композитного планера БПЛА вертикального взлёта и посадки Innovtol 3, а также других беспилотных летательных аппаратов. Иногда провожу тестовые полёты и снимаю их с помощью квадрокоптеров.
#
# Моё хобби тоже связано с техникой и полётами — это дрон-рейсинг — соревнование профессиональных или начинающих пилотов квадрокоптеров, которые на скорость преодолевают специальные трассы с препятствием. Это зрелищный и технически непростой спорт: нужно уметь самому собирать и ремонтировать гоночный дрон, управлять им через пульт и очки, ещё и постараться не врезаться в препятствия или дрон соперника. Этим летом я с коллегами из университета впервые организовывал гонку дронов Skyrace в Иннополисе. В соревновании участвовали 65 спортсменов из России, Беларуси и Казахстана, я и сам летал, правда, не прошёл в полуфинал.
#
# А в «нелётное» время года иногда собираю стендовые модели авиатехники: вертолёты, советские самолёты, современные отечественные истребители. Какие-то дополнительные детали, например, пилотов печатаю на 3D-принтере.
# Руслан Лукин, руководитель Лаборатории искусственного интеллекта в новых материалах Университета Иннополис
#
# Сферы моих научных интересов — хемоинформатика, а также глубокое обучение для материалов и молекул. Сейчас мы с коллегами работаем над созданием алгоритмов и платформы для разработки лекарств на основе глубоких графовых нейросетей и алгоритмов. Также есть проект по поиску новых мишеней — генов или белков — на основе графов знаний и языковых моделей. Ещё занимаюсь применением глубокого обучения для поиска новых катализаторов для возобновляемой энергетики.
#
# Лучшие идеи или решения довольно сложных, на первый взгляд, задач в моих проектах приходили во время катания на лонгборде. Изначально я планировал заниматься скейтбордингом, изучать трюки, но лонгборд привлёк тем, что позволяет путешествовать по городу так же свободно как и на велосипеде, но с ощущением как от сёрфинга. В сезон имею привычку катать лонг-дистанс по 3 часа перед сном — выходит порядка 20 км по городу. Каждый раз стараюсь менять маршруты с учётом качества дорожного покрытия и плейлиста для катания.
#
# В принципе, связь лонгбординга с наукой заканчивается на изучении на собственном теле понятий центра массы и баланса, а также аэродинамики. В моем случае это хобби — полноценная альтернатива кардиотренировкам и способ генерировать идеи «на лету». В целом, лонгборд и круизинг, скорее, коррелируются с моими увлечениями всем, что движется на колесах: мне нравится ездить и получать как можно больше визуальных впечатлений в единицу времени.
