# %% [markdown]
# # Implementation of a solution using Retrieval Augmented Generation with LLM based on LlamaIndex framework

# %% [markdown]
# ### Data preparation
#
# Flatten all text files into raw folder

# %%
import os
import shutil


def copy_text_files(source_dir, destination_dir):
    # Create the destination directory if it doesn't exist
    if not os.path.exists(destination_dir):
        os.makedirs(destination_dir)

    # Traverse the source directory
    for root, dirs, files in os.walk(source_dir):
        for file in files:
            # Check if the file has a .txt extension (you can modify this condition)
            if file.endswith(".txt") or file.endswith(".md"):
                source_path = os.path.join(root, file)
                destination_path = os.path.join(destination_dir, 'raw_' + root.split('/')[-1] + '_' + file)

                # Copy the file to the destination directory
                shutil.copy2(source_path, destination_path)
                print(f"Copied: {file}")

# Replace 'source_directory' and 'destination_directory' with your actual paths
copy_text_files('../data/documents/', '../data/raw')
copy_text_files('../data/documents/edu-wiki', '../data/raw')
# Out:
# Copied: 11. Volunteering & Innopoints.md
# Copied: 2. Accommodation & Meal Plan.md
# Copied: 5. How to Order References?.md
# Copied: 12. Migration Control for International Students.md
# Copied: 9.5. Exchange Opportunities.md
# Copied: 13. Library.md
# Copied: 1. Academic Plan.md
# Copied: 9. Rules of registration for the military service:.md
# Copied: 8. Scholarships & Financial Support.md
# Copied: 10. Your Health.md
# Copied: Extracurricular.md
# Copied: Admin.md
# Copied: Academic.md
# Copied: Household.md
# Copied: apply.innopolis.university_master.txt
# Copied: apply.innopolis.university_grant.txt
# Copied: innopolis.university_sveden_apply.txt
# Copied: apply.innopolis.university_olymp-math.txt
# Copied: apply.innopolis.ru_get-in.txt
# Copied: apply.innopolis.university_olympiad-bonus.txt
# Copied: apply.innopolis.university_faq.txt
# Copied: career.innopolis.university.txt
# Copied: itproductdevelopment.md
# Copied: venturecapitalhacksfromzerotonegotiatinganinvestmentdeal.tex.md
# Copied: introductiontoitentrepreneurship.tex.md
# Copied: innovativeagilesoftwaredevelopmentmethodologyforhighreliabilityandmissioncriticalapplications.tex.md
# Copied: communicationforstartupsfrombootstaptoglobalmarkets.tex.md
# Copied: internationaltradeproceduresandregulations.tex.md
# Copied: leanstartupmethodology.tex.md
# Copied: formalsoftwaredevelopmentofandroidapps.tex.md
# Copied: softwareprojectmanagement.tex.md
# Copied: theprinciplesandpracticeofimportexport.tex.md
# Copied: bitcoinandcryptocurrencytechnologies.tex.md
# Copied: informationretrievalfordatascience.tex.md
# Copied: patternorienteddesign.tex.md
# Copied: fearlessideas.tex.md
# Copied: nocodeandlowcodedevelopment.md
# Copied: digitalsignalprocessing.tex.md
# Copied: negotiatingprocessesforthepromotionofcooperationandhumanrightsininternationalregimeshistory.tex.md
# Copied: proceduralcontentgenerationforgames.tex.md
# Copied: algorithmsofmachinelearning.tex.md
# Copied: humancomputerinteractiondesign.tex.md
# Copied: introductiontoconvexoptimization.tex.md
# Copied: introductiontocareerdevelopment.tex.md
# Copied: programminginhaskell.tex.md
# Copied: fundamentalsofinformationsecurity.tex.md
# Copied: industrialcpp.tex.md
# Copied: distributedsystemsandmiddlewarepatternsandframeworks.tex.md
# Copied: moderncppnewlanguageconceptsfeaturesandmechanisms.tex.md
# Copied: concurrentobjectorientedprogrammingwithscoop.tex.md
# Copied: functionalprogrammingandscalalanguage.tex.md
# Copied: industrialsoftwaretesting.tex.md
# Copied: userexperienceanduserinterfacedesignfundamentals.tex.md
# Copied: windowskernelarchitectureanddrivers.tex.md
# Copied: entrepreneurship.tex.md
# Copied: reverseengineering.tex.md
# Copied: productdesign.tex.md
# Copied: esportsindustrymarketingeconomyandgamedesign.tex.md
# Copied: digitalinnovationandentrepreneurship.tex.md
# Copied: frontendwebdevelopment.tex.md
# Copied: introductiontocommunication.tex.md
# Copied: practicalartificialintelligence.tex.md
# Copied: internationalbusinesslegalessentials.tex.md
# Copied: fundamentalsrobotcontrol.tex.md
# Copied: advancedalgorithmsforartificialintelligence.tex.md
# Copied: naturallanguageprocessingandmachinelearning.tex.md
# Copied: philosophyofinformation.tex.md
# Copied: decentralizedapplicationsonethereumplatform.tex.md
# Copied: advancedsoftwaredesign.tex.md
# Copied: economicsofentrepreneurship.tex.md
# Copied: industrialprogramminginjava.tex.md
# Copied: ethicsandit.tex.md
# Copied: thesis_guidelines.md
# Copied: what_if_i_failed.md
# Copied: mirkofarina.md
# Copied: vladimirivanov.md
# Copied: backups.md
# Copied: maratmingazov.md
# Copied: physical_culture_and_sport_exercise_physiology_mindfulness.md
# Copied: evgeniizouev.md
# Copied: newsboard.md
# Copied: the_guidelines_%26_faq_for_offering_elective_courses_at_innopolis_university.md
# Copied: adilkhan.md
# Copied: almaoracevic.md
# Copied: sergeygorodetsky.md
# Copied: main_page.md
# Copied: nikolaykudasov.md
# Copied: nikolayshilov.md
# Copied: georgygelvanovsky.md
# Copied: mansurkhazeev.md
# Copied: ms1and2.md
# Copied: faq_for_offering_an_elective.md
# Copied: information_page_about_study_process_in_moodle.md
# Copied: oksanazhirosh.md
# Copied: list_of_bsc_humanitarian_electives.md
# Copied: general_information.md
# Copied: kirillpoletkin.md
# Copied: scientific_sources_and_material.md
# Copied: electives.md
# Copied: professors.md
# Copied: igorgaponov.md
# Copied: exchange.md
# Copied: list_of_msc_technical_electives.md
# Copied: aleksandrmaloletov.md
# Copied: munirmakhmutov.md
# Copied: information_page_about_study_process.md
# Copied: newsboard,_channels_and_groups_links.md
# Copied: guzelfazlyeva.md
# Copied: list_of_all_courses.md
# Copied: yaroslavkholodov.md
# Copied: about_lecturing_a_course.md
# Copied: anastasiyapuzankova.md
# Copied: giancarlosucci.md
# Copied: alexandertormasov.md
# Copied: nursultanaskarbekuly.md
# Copied: evgeniyakruglova.md
# Copied: msccalendar.md
# Copied: ivankonyukhov.md
# Copied: ahsankazmi.md
# Copied: scientificsourcesandmaterial.md
# Copied: stanislavprotasov.md
# Copied: newcomer%27s.md
# Copied: employmentsupports.md
# Copied: how_to_moodle.md
# Copied: alexanderklimchik.md
# Copied: artemkruglov.md
# Copied: thesisguidelines.md
# Copied: technical_electives.md
# Copied: andreyfrolov.md
# Copied: sergeysavin.md
# Copied: josephbrown.md
# Copied: semenkurkin.md
# Copied: winter_school.md
# Copied: humanitarian_electives.md
# Copied: ruslansaduov.md
# Copied: manuelmazzara.md
# Copied: rasheedhussain.md
# Copied: phd.md
# Copied: overallregulations.md
# Copied: professor_information_page.md
# Copied: olegkiselev.md
# Copied: luizaraujo.md
# Copied: howtomoodle.md
# Copied: innopolisuniversitymanifestoonmedium.md
# Copied: whatififailed.md
# Copied: exchange_program_%26_summer_school.md
# Copied: faqinstructors.md
# Copied: academicleave.md
# Copied: saifmohammedsabri.md
# Copied: the_guidelines_%26_faq_for_offering_elective_courses.md
# Copied: nursultan_askarbekuly.md
# Copied: educational_opportunities_for_alumni.md
# Copied: rababmarouf.md
# Copied: bscphysicalcultureandsportexercisephysiologymindfulness.md
# Copied: list_of_electives.md
# Copied: academic_leave.md
# Copied: employment_supports_and_educational_opportunities_for_alumni.md
# Copied: mohammedrezabahrami.md
# Copied: paolociancarini.md
# Copied: faqstudents.md
# Copied: olegbulichev.md
# Copied: howtomoodlerus.md
# Copied: summer_school.md
# Copied: professorinformationpage.md
# Copied: about_this_document.md
# Copied: list_of_core_courses.md
# Copied: list_of_msc_humanitarian_electives.md
# Copied: structure_of_the_bs_degrees.md
# Copied: employment_supports.md
# Copied: faqforofferingelective.md
# Copied: kirillsaltanov.md
# Copied: list_of_bsc_technical_electives.md
# Copied: listofpublications.md
# Copied: academiccalendar.md
# Copied: exchange_program.md
# Copied: studentinformationpage.md
# Copied: artemburmyakov.md
# Copied: andreysadovykh.md
# Copied: itproductdevelopment.md
# Copied: _fundraising,_go_to_market_and_hyper_growth_for_startups.md
# Copied: designfiction.md
# Copied: _human_and_animal_brain_representation_in_neurosciences.md
# Copied: techstartudesign.md
# Copied: _introduction_to_it_entrepreneurship.md
# Copied: scienceethics.md
# Copied: introductiontoitentrepreneurship.md
# Copied: _leadership_in_entrepreneurship.md
# Copied: _career_and_leadership.md
# Copied: _developing_entrepreneurial_skills_for_a_startup_founder.md
# Copied: introductiontocareerdevelopment.md
# Copied: venture_capital_hacks_in_it_industry:_from_zero_to_negotiating_and_investment_deal.md
# Copied: introductiontoeconomicsofentrepreneurship.md
# Copied: venturecapitalhacksinitindustry.md
# Copied: _it_product_development.md
# Copied: empiricalmethods.md
# Copied: syllabi_index.md
# Copied: high-dimensional_data_analysis.md
# Copied: dynamicsofnonlinearroboticsystems.f21.md
# Copied: _advanced_information_retrieval.md
# Copied: controltheorylinearcontrol.md
# Copied: _venture_capital_and_growth_hacking.md
# Copied: _advanced_statistics.md
# Copied: advanced_robotics.md
# Copied: offensivetechnologies.s22.md
# Copied: models_software_systems.md
# Copied: classicalinternetapplications.f21.md
# Copied: _optimization.md
# Copied: _advanced_security.md
# Copied: _machine_learning.md
# Copied: computationalintelligence.s22.md
# Copied: _requirements_engineering.md
# Copied: datamining.md
# Copied: inter_networking_and_routing.md
# Copied: securitysystemsnetworks.md
# Copied: managingsoftwaredevelopment.f21.md
# Copied: randomizedalgorithms.md
# Copied: advanced_security.md
# Copied: datamodelinganddatabases2.md
# Copied: highdimensionaldataanalysis.s22.md
# Copied: _inter_networking_and_routing.md
# Copied: _security_of_systems_and_networks.md
# Copied: managingsoftwaredevelopment%d1%8e.f21.md
# Copied: _founder_project.md
# Copied: internetworkingandrouting.md
# Copied: computer_vision.md
# Copied: modelssoftwaresystems.s22.md
# Copied: _large_systems.md
# Copied: classical_internet_applications.md
# Copied: _personal_software_process.md
# Copied: _secure_development.md
# Copied: dynamicsofnonlinearroboticsystems.md
# Copied: _syllabi_index.md
# Copied: advancedstatistics.s22.md
# Copied: requirements_engineering.md
# Copied: computational_intelligence.md
# Copied: advancedinformationretrieval.md
# Copied: architectures_software_systems.md
# Copied: _computer_vision.md
# Copied: advancednetworking.f21.md
# Copied: advancedrobotics.s22.md
# Copied: metricsandempiricalmethods.md
# Copied: unit-economicsforitstartups.md
# Copied: _communication.md
# Copied: analysis_software_artifacts.md
# Copied: oopandsoftwarearchitechture.md
# Copied: optimization.md
# Copied: communication.s22.md
# Copied: humanitarianelectives.md
# Copied: bigdatatechnologiesandanalytics.md
# Copied: _models_software_systems.md
# Copied: machinelearning.f21.md
# Copied: personalsoftwareprocess.md
# Copied: _analysis_software_artifacts.md
# Copied: _architectures_of_software_systems.md
# Copied: architecturessoftwaresystems.md
# Copied: largesystems.s22.md
# Copied: advancedsecurity.md
# Copied: bigdatatechnologiesandanalytics.f21.md
# Copied: gametheory.md
# Copied: cybercrime_forensics.md
# Copied: analysissoftwareartifacts.md
# Copied: advancedinformationretrieval.s22.md
# Copied: big_data_technologies_and_analytics.md
# Copied: syllabi_table.md
# Copied: architecturessoftwaresystems.s22.md
# Copied: _empirical_methods.md
# Copied: sensingperceptionactuation.f21.md
# Copied: analysissoftwareartifacts.s22.md
# Copied: communication.md
# Copied: advancedstatistics.md
# Copied: _managing_software_development.md
# Copied: advanced_statistics.md
# Copied: _fundamentals_of_robot_control.md
# Copied: classicalinternetapplications.md
# Copied: _advanced_machine_learning.md
# Copied: advanced_networking.md
# Copied: internetworkingandrouting.f21.md
# Copied: sensing_perception_actuation.md
# Copied: _it_product_development.md
# Copied: advancedmachinelearning.s22.md
# Copied: sensingperceptionactuation.md
# Copied: largeinstallationadministration.md
# Copied: computervision.md
# Copied: technicalelectives.md
# Copied: _advanced_robotics.md
# Copied: informationtheory.md
# Copied: _venture_and_growth_hacking.md
# Copied: advancednetworking.md
# Copied: _ceo_toolkit_strategy,_operations,_finance,_hr,_legal_aspects,_ip_law_and_innovations.md
# Copied: computationalintelligence.md
# Copied: advancedrobotics.md
# Copied: datasecurity.md
# Copied: empirical_methods.md
# Copied: _it_business_start.md
# Copied: advanced_information_retrieval.md
# Copied: advancedsecurity.s22.md
# Copied: _msc:_secure_development.md
# Copied: _sensing_perception_actuation.md
# Copied: managinsoftwaredevelopment_block1.md
# Copied: requirementsengineering.md
# Copied: _unit_economics_in_it_business.md
# Copied: empiricalmethods.f21.md
# Copied: architectures_of_software_systems.md
# Copied: distributedsystems.md
# Copied: personal_software_process.md
# Copied: offensivetechnologies.md
# Copied: probabilitystatistics.md
# Copied: large_systems.md
# Copied: managing_software_development.md
# Copied: _leadership_in_entrepreneurship.md
# Copied: offensive_technologies.md
# Copied: dynamics_of_non_linear_robotic_systems.md
# Copied: securityofsystemsandnetworks.md
# Copied: machine_learning.md
# Copied: fundamentalsofrobotcontrol.md
# Copied: advanced_machine_learning.md
# Copied: _offensive_technologies.md
# Copied: highdimensionaldataanalysis.md
# Copied: modelssoftwaresystems.md
# Copied: _cybercrime_forensics.md
# Copied: machinelearning.md
# Copied: computervision.s22.md
# Copied: unit-economics_for_it_startups.md
# Copied: cybercrimeforensics.md
# Copied: _dynamics_of_non_linear_robotic_systems.md
# Copied: _advanced_networking.md
# Copied: managinsoftwaredevelopment_block2.md
# Copied: researchmethods.md
# Copied: _marketing_and_sales_for_it_business.md
# Copied: cybercrimeforensics.s22.md
# Copied: _unit-economics_for_it_startups.md
# Copied: _high-dimensional_data_analysis.md
# Copied: requirementsengineering.f21.md
# Copied: _computational_intelligence.md
# Copied: managingsoftwaredevelopment.md
# Copied: _classical_internet_applications.md
# Copied: analyticalgeometryandlinearalgebrai.md
# Copied: behavioralandcognitiverobotics.md
# Copied: advancedmachinelearning.md
# Copied: personalsoftwareprocess.f21.md
# Copied: _big_data_technologies_and_analytics.md
# Copied: optimization.f21.md
# Copied: neuroscience.md
# Copied: _security_and_interpretability_of_machine_learning.md
# Copied: highperformancecomputing.md
# Copied: reinforcmentlearning.md
# Copied: _cross-platform_mobile_development_with_flutter.md
# Copied: introductiontofunctionalprogrammingandscalalanguage.md
# Copied: marketresearchforitstartups.md
# Copied: _art_of_reading_learning_and_understanding.md
# Copied: itproductdevelopment.md
# Copied: servicedesign.md
# Copied: _applied_machine_learning.md
# Copied: frontendwebdevelopment.md
# Copied: advancedtopicsinsoftwaretesting.md
# Copied: _distributed_systems.md
# Copied: _the_security_and_interpretability_of_machine_learning.md
# Copied: proceduralcontentgenerationforgames.md
# Copied: _advanced_linux.md
# Copied: introductiontopracticalartificialintelligence.md
# Copied: introductiontoquantumprogramming.md
# Copied: advancedcpp.md
# Copied: _computer_graphics_in_game_development.md
# Copied: distributedsystemsandmiddleware.md
# Copied: discretemathandlogic.md
# Copied: advanced_algorithms.md
# Copied: softwarearchitectures.md
# Copied: _probability_and_statistics.f23.md
# Copied: syllabi_index.md
# Copied: _academic_research_and_writing_culture_ii.md
# Copied: statisticaltechniquesfordatascience.s21.md
# Copied: practicalmachinelearningdeeplearning.md
# Copied: fundamentalsofcomputersecurity.md
# Copied: humanitieselectives.md
# Copied: academicresearchandwritingculture.md
# Copied: _capstone_project.md
# Copied: _differential_equations.f22.md
# Copied: _total_virtualization.md
# Copied: digitalsignalprocessing.md
# Copied: _software_quality,_reliability_and_security.md
# Copied: introductiontoprogramming.md
# Copied: datastructuresalgorithmsii.md
# Copied: softwarearchitectures.old.md
# Copied: _statistical_techniques_for_data_science.md
# Copied: networks.md
# Copied: networks.s22.md
# Copied: logic_and_discrete_mathematics.f21.md
# Copied: _game_theory.md
# Copied: naturallanguageprocessing.md
# Copied: _dev_ops_engineering.md
# Copied: _advanced_compilers_construction_and_program_analysis.md
# Copied: academicresearchandwritingculture2.s22.md
# Copied: distributedledgerstechnologies.md
# Copied: introductiontoprogramming.f21.md
# Copied: _compilers_construction.md
# Copied: softwaresystemsdesign.f21.md
# Copied: theoreticalcomputerscience.s22.md
# Copied: distributedandnetworkprogramming.f21.md
# Copied: _introduction_to_robotics.md
# Copied: _mechatronics.md
# Copied: _networks.md
# Copied: physicalcultureandsport.md
# Copied: _history.md
# Copied: _reinforcement_learning.md
# Copied: systemtheory.md
# Copied: sensorsandsensing.md
# Copied: datamining.md
# Copied: _analytic_geometry_and_linear_algebra_i.f22.md
# Copied: fundamentalsofgraphicsandvirtualrealities.md
# Copied: informationretrieval.md
# Copied: mathematicalanalysisi.f21.md
# Copied: devopsengineering.md
# Copied: _introduction_to_artificial_intelligence.md
# Copied: mathematicalmodeling.md
# Copied: _software_project.md
# Copied: nonlinearcontroltheory.md
# Copied: computerarchitecture.f21.md
# Copied: _physical_culture_and_sport_psychology.md
# Copied: systemandnetworkadministration.f21.md
# Copied: computerarchitecture.md
# Copied: roboticsystems.md
# Copied: _probability_and_statistics.f22.md
# Copied: _secure_system_development.md
# Copied: softwareverificationtesting.md
# Copied: compilersconstruction.s22.md
# Copied: analyticgeometryandlinearalgebrai.f21.md
# Copied: _introduction_to_programming_ii.md
# Copied: statisticaltechniquesfordatascience..md
# Copied: _human-ai_interaction_design.md
# Copied: _introduction_to_computer_vision.md
# Copied: embeddedandsharedmemoryprogramming.md
# Copied: _lean_software_development.md
# Copied: mathematicalanalysisii.f21.md
# Copied: history.f21.md
# Copied: datamining.s22.md
# Copied: phil1-introductiontologic.md
# Copied: introductiontoprogrammingi.old.md
# Copied: introductiontoprogrammingi.md
# Copied: logic_and_discrete_mathematics.md
# Copied: advanceddatabases.s22.md
# Copied: analyticgeometryandlinearalgebrai.md
# Copied: distributedsytemsandcloudcomputing.md
# Copied: _data_structures_algorithms.md
# Copied: numericalmodelling.md
# Copied: softwarequalityandreliability.md
# Copied: _distributed_and_network_programming.md
# Copied: _mathematical_analysis_ii.md
# Copied: securesystemdevelopment.md
# Copied: leansoftwaredevelopment.s22.md
# Copied: analyticgeometryandlinearalgebraii.md
# Copied: naturallanguageprocessing.s22.md
# Copied: englishforacademicpurposesii.s22.md
# Copied: history.md
# Copied: informationretrieval.s22.md
# Copied: controltheory.s22.md
# Copied: roboticsystems.s22.md
# Copied: _analytic_geometry_and_linear_algebra_ii.s23.md
# Copied: mathematicalanalysisii.s22.md
# Copied: microcontrollersandembeddedhardware.md
# Copied: physicsi.f21.md
# Copied: networkandcybersecurity.md
# Copied: _nature_inspired_computing.md
# Copied: datamodelingdatabasesii.md
# Copied: _introduction_to_big_data.md
# Copied: programmingparadigms.f21.md
# Copied: businessanalytics.md
# Copied: _theoretical_mechanics.md
# Copied: introductiontoartificialintelligence.md
# Copied: _practical_machine_learning_deep_learning.md
# Copied: _introduction_to_machine_learning.md
# Copied: .md
# Copied: _system_and_network_administration.md
# Copied: networkandcybersecurity.s22.md
# Copied: gametheory.md
# Copied: syllabi_table.md
# Copied: compilersconstruction.md
# Copied: _theoretical_computer_science.md
# Copied: _analytic_geometry_and_linear_algebra_ii.md
# Copied: englishforacademicpurposesi.md
# Copied: statisticaltechniquesfordatascience.s22.md
# Copied: academicresearchandwritingculture2.md
# Copied: _software_architectures.md
# Copied: mechatronics.md
# Copied: devopsengineering.f21.md
# Copied: _probability_and_statistics.md
# Copied: mobileapplicationdevelopment.md
# Copied: physicsi.md
# Copied: fundamentals.md
# Copied: _mathematical_analysis_i.f21.test.md
# Copied: _computer_architecture.md
# Copied: introductiontomachinelearning.md
# Copied: physicsii.md
# Copied: natureinspiredcomputing.md
# Copied: softwareproject.md
# Copied: mobileapplicationdevelopment-1.md
# Copied: advancedcompilersconstructionandprogramanalysis.md
# Copied: _mathematical_analysis_ii.s23.md
# Copied: _academic_research_and_writing_culture.md
# Copied: fundamentals_of_computer_security.md
# Copied: _operating_systems.md
# Copied: _analytic_geometry_and_linear_algebra_i.f21.md
# Copied: _introduction_to_programming.md
# Copied: mechanicsandmachines.s22.md
# Copied: _signals_and_systems.md
# Copied: introductiontorobotics.md
# Copied: _mathematical_analysis_i.md
# Copied: _it_product_development.md
# Copied: _analytic_geometry_and_linear_algebra_i.f23.md
# Copied: mathematicalanalysisii.md
# Copied: nonlinearoptimization.md
# Copied: _analytic_geometry_and_linear_algebra_i.md
# Copied: _mathematical_analysis_i.f22.md
# Copied: _advanced_databases.md
# Copied: signalsandsystems.md
# Copied: philosophyii.md
# Copied: _analytic_geometry_and_linear_algebra_ii.s22.md
# Copied: informationtheory.md
# Copied: humancomputerinterfaces.md
# Copied: physicsii.s22.md
# Copied: _control_theory.md
# Copied: introductiontocomputervision.f21.md
# Copied: theoreticalmechanics.md
# Copied: probabilityandstatistics.md
# Copied: leansoftwaredevelopment.md
# Copied: introductiontobigdata.md
# Copied: introductiontobigdata.f21.md
# Copied: _data_mining.md
# Copied: softwarequalityandreliability.s21.md
# Copied: controltheory.md
# Copied: programmingparadigms.md
# Copied: technicalelective.md
# Copied: _logic_and_discrete_mathematics.md
# Copied: _mathematical_analysis_i.f21.md
# Copied: mathematicalanalysisi.md
# Copied: introductiontomachinelearning.f21.md
# Copied: gametheory.s22.md
# Copied: _differential_equations.f23.md
# Copied: analyticalgeometryandlinearalgebrai-cs.md
# Copied: mathematicalanalysisii.s23.md
# Copied: advancedcompilerconstructionandprogramanalysis.md
# Copied: _differential_equations.md
# Copied: _network_and_cyber_security.md
# Copied: softwaresystemsdesign.md
# Copied: _mechanics_and_machines.md
# Copied: practicalmachinelearningdeeplearning.f21.md
# Copied: operatingsystems.f21.md
# Copied: _programming_paradigms.md
# Copied: introductiontocomputervision.md
# Copied: logicincomputerscience.md
# Copied: _physics_ii.md
# Copied: _advanced_linux.md
# Copied: _information_retrieval.md
# Copied: advancedalgorithms.md
# Copied: _robotic_systems.md
# Copied: introductiontoprogrammingii.s22.md
# Copied: _physics_i.md
# Copied: datastructuresalgorithms.md
# Copied: _introduction_to_optimization.f22.md
# Copied: _philosophy_ii.md
# Copied: sensorsandsensing.s22.md
# Copied: cloudcomputing.md
# Copied: project.md
# Copied: phil2-knowledgeandperception.md
# Copied: differentialequations.md
# Copied: physicalcultureandsport.s22.md
# Copied: logic_and_discrete_mathematics.f22.md
# Copied: introductiontoprogrammingii.md
# Copied: analyticgeometryandlinearalgebraii.s22.md
# Copied: _sensors_and_sensing.md
# Copied: introductiontoartificialintelligence.s22.md
# Copied: englishforacademicpurposesi.f21.md
# Copied: _introduction_to_artificial_intelligence.s22.md
# Copied: mechanicsandmachines.md
# Copied: operatingsystems.md
# Copied: _software_systems_design.md
# Copied: fundamentalsofsoftwareengineering.md
# Copied: datamodelingdatabasesi.md
# Copied: differentialequations.f21.md
# Copied: theoreticalcomputerscience.md
# Copied: philosophyi.f21.md
# Copied: englishforacademicpurposesii.md
# Copied: _fundamentals_of_computer_security.md
# Copied: probabilityandstatistics.f21.md
# Copied: theoreticalmechanics.f21.md
# Copied: statisticaltechniquesfordatascience.md
# Copied: systemandnetworkadministration.md
# Copied: principelsofcomputersecurity.md
# Copied: _natural_language_processing.md
# Copied: signalsandsystems.s22.md
# Copied: operatingsystems%d1%8e.f21.md
# Copied: _probability_and_statistics.s22.md
# Copied: distributedandnetworkprogramming.md
# Copied: introductiontorobotics.f21.md
# Copied: advanceddatabases.md
# Copied: philosophyii.f21.md
# Copied: _physical_culture_and_sport_nutrition.md
# Copied: syllabi_table_3%2b11.md
# Copied: mechatronics.f21.md
# Copied: syllabi_table_3%2b1.md
# Copied: advancedcompilersconstructionandprogramanalysis.s22.md
# Copied: _ceo_toolkit.md
# Copied: _mste:_it_course.md
# Copied: _market_research_for_it_startups.md
# Copied: _analysis_of_software_artifacts.md
# Copied: _introduction_to_programming.md
# Copied: _it_product_development.md
# Copied: _leadership_in_entrepreneurship.md
# Copied: _it_course.md
# Copied: academicresearchandwritingculture.md
# Copied: syllabi_table.md
# Copied: founderproject.md
# Copied: itproductdevelopment.md
# Copied: ceotoolkit:strategy,operations,finance,hr,legalaspects,iplawandinnovations.md
# Copied: schedule.md
# Copied: studyplan.md
# Copied: Tech clubs.md
# Copied: Art clubs.md
# Copied: Sport clubs.md
# Copied: Special interest clubs.md
# Copied: clubs.md
# Copied: itproductdevelopment.md
# Copied: venturecapitalhacksfromzerotonegotiatinganinvestmentdeal.tex.md
# Copied: introductiontoitentrepreneurship.tex.md
# Copied: innovativeagilesoftwaredevelopmentmethodologyforhighreliabilityandmissioncriticalapplications.tex.md
# Copied: communicationforstartupsfrombootstaptoglobalmarkets.tex.md
# Copied: internationaltradeproceduresandregulations.tex.md
# Copied: leanstartupmethodology.tex.md
# Copied: formalsoftwaredevelopmentofandroidapps.tex.md
# Copied: softwareprojectmanagement.tex.md
# Copied: theprinciplesandpracticeofimportexport.tex.md
# Copied: bitcoinandcryptocurrencytechnologies.tex.md
# Copied: informationretrievalfordatascience.tex.md
# Copied: patternorienteddesign.tex.md
# Copied: fearlessideas.tex.md
# Copied: nocodeandlowcodedevelopment.md
# Copied: digitalsignalprocessing.tex.md
# Copied: negotiatingprocessesforthepromotionofcooperationandhumanrightsininternationalregimeshistory.tex.md
# Copied: proceduralcontentgenerationforgames.tex.md
# Copied: algorithmsofmachinelearning.tex.md
# Copied: humancomputerinteractiondesign.tex.md
# Copied: introductiontoconvexoptimization.tex.md
# Copied: introductiontocareerdevelopment.tex.md
# Copied: programminginhaskell.tex.md
# Copied: fundamentalsofinformationsecurity.tex.md
# Copied: industrialcpp.tex.md
# Copied: distributedsystemsandmiddlewarepatternsandframeworks.tex.md
# Copied: moderncppnewlanguageconceptsfeaturesandmechanisms.tex.md
# Copied: concurrentobjectorientedprogrammingwithscoop.tex.md
# Copied: functionalprogrammingandscalalanguage.tex.md
# Copied: industrialsoftwaretesting.tex.md
# Copied: userexperienceanduserinterfacedesignfundamentals.tex.md
# Copied: windowskernelarchitectureanddrivers.tex.md
# Copied: entrepreneurship.tex.md
# Copied: reverseengineering.tex.md
# Copied: productdesign.tex.md
# Copied: esportsindustrymarketingeconomyandgamedesign.tex.md
# Copied: digitalinnovationandentrepreneurship.tex.md
# Copied: frontendwebdevelopment.tex.md
# Copied: introductiontocommunication.tex.md
# Copied: practicalartificialintelligence.tex.md
# Copied: internationalbusinesslegalessentials.tex.md
# Copied: fundamentalsrobotcontrol.tex.md
# Copied: advancedalgorithmsforartificialintelligence.tex.md
# Copied: naturallanguageprocessingandmachinelearning.tex.md
# Copied: philosophyofinformation.tex.md
# Copied: decentralizedapplicationsonethereumplatform.tex.md
# Copied: advancedsoftwaredesign.tex.md
# Copied: economicsofentrepreneurship.tex.md
# Copied: industrialprogramminginjava.tex.md
# Copied: ethicsandit.tex.md
# Copied: thesis_guidelines.md
# Copied: what_if_i_failed.md
# Copied: mirkofarina.md
# Copied: vladimirivanov.md
# Copied: backups.md
# Copied: maratmingazov.md
# Copied: physical_culture_and_sport_exercise_physiology_mindfulness.md
# Copied: evgeniizouev.md
# Copied: newsboard.md
# Copied: the_guidelines_%26_faq_for_offering_elective_courses_at_innopolis_university.md
# Copied: adilkhan.md
# Copied: almaoracevic.md
# Copied: sergeygorodetsky.md
# Copied: main_page.md
# Copied: nikolaykudasov.md
# Copied: nikolayshilov.md
# Copied: georgygelvanovsky.md
# Copied: mansurkhazeev.md
# Copied: ms1and2.md
# Copied: faq_for_offering_an_elective.md
# Copied: information_page_about_study_process_in_moodle.md
# Copied: oksanazhirosh.md
# Copied: list_of_bsc_humanitarian_electives.md
# Copied: general_information.md
# Copied: kirillpoletkin.md
# Copied: scientific_sources_and_material.md
# Copied: electives.md
# Copied: professors.md
# Copied: igorgaponov.md
# Copied: exchange.md
# Copied: list_of_msc_technical_electives.md
# Copied: aleksandrmaloletov.md
# Copied: munirmakhmutov.md
# Copied: information_page_about_study_process.md
# Copied: newsboard,_channels_and_groups_links.md
# Copied: guzelfazlyeva.md
# Copied: list_of_all_courses.md
# Copied: yaroslavkholodov.md
# Copied: about_lecturing_a_course.md
# Copied: anastasiyapuzankova.md
# Copied: giancarlosucci.md
# Copied: alexandertormasov.md
# Copied: nursultanaskarbekuly.md
# Copied: evgeniyakruglova.md
# Copied: msccalendar.md
# Copied: ivankonyukhov.md
# Copied: ahsankazmi.md
# Copied: scientificsourcesandmaterial.md
# Copied: stanislavprotasov.md
# Copied: newcomer%27s.md
# Copied: employmentsupports.md
# Copied: how_to_moodle.md
# Copied: alexanderklimchik.md
# Copied: artemkruglov.md
# Copied: thesisguidelines.md
# Copied: technical_electives.md
# Copied: andreyfrolov.md
# Copied: sergeysavin.md
# Copied: josephbrown.md
# Copied: semenkurkin.md
# Copied: winter_school.md
# Copied: humanitarian_electives.md
# Copied: ruslansaduov.md
# Copied: manuelmazzara.md
# Copied: rasheedhussain.md
# Copied: phd.md
# Copied: overallregulations.md
# Copied: professor_information_page.md
# Copied: olegkiselev.md
# Copied: luizaraujo.md
# Copied: howtomoodle.md
# Copied: innopolisuniversitymanifestoonmedium.md
# Copied: whatififailed.md
# Copied: exchange_program_%26_summer_school.md
# Copied: faqinstructors.md
# Copied: academicleave.md
# Copied: saifmohammedsabri.md
# Copied: the_guidelines_%26_faq_for_offering_elective_courses.md
# Copied: nursultan_askarbekuly.md
# Copied: educational_opportunities_for_alumni.md
# Copied: rababmarouf.md
# Copied: bscphysicalcultureandsportexercisephysiologymindfulness.md
# Copied: list_of_electives.md
# Copied: academic_leave.md
# Copied: employment_supports_and_educational_opportunities_for_alumni.md
# Copied: mohammedrezabahrami.md
# Copied: paolociancarini.md
# Copied: faqstudents.md
# Copied: olegbulichev.md
# Copied: howtomoodlerus.md
# Copied: summer_school.md
# Copied: professorinformationpage.md
# Copied: about_this_document.md
# Copied: list_of_core_courses.md
# Copied: list_of_msc_humanitarian_electives.md
# Copied: structure_of_the_bs_degrees.md
# Copied: employment_supports.md
# Copied: faqforofferingelective.md
# Copied: kirillsaltanov.md
# Copied: list_of_bsc_technical_electives.md
# Copied: listofpublications.md
# Copied: academiccalendar.md
# Copied: exchange_program.md
# Copied: studentinformationpage.md
# Copied: artemburmyakov.md
# Copied: andreysadovykh.md
# Copied: itproductdevelopment.md
# Copied: _fundraising,_go_to_market_and_hyper_growth_for_startups.md
# Copied: designfiction.md
# Copied: _human_and_animal_brain_representation_in_neurosciences.md
# Copied: techstartudesign.md
# Copied: _introduction_to_it_entrepreneurship.md
# Copied: scienceethics.md
# Copied: introductiontoitentrepreneurship.md
# Copied: _leadership_in_entrepreneurship.md
# Copied: _career_and_leadership.md
# Copied: _developing_entrepreneurial_skills_for_a_startup_founder.md
# Copied: introductiontocareerdevelopment.md
# Copied: venture_capital_hacks_in_it_industry:_from_zero_to_negotiating_and_investment_deal.md
# Copied: introductiontoeconomicsofentrepreneurship.md
# Copied: venturecapitalhacksinitindustry.md
# Copied: _it_product_development.md
# Copied: empiricalmethods.md
# Copied: syllabi_index.md
# Copied: high-dimensional_data_analysis.md
# Copied: dynamicsofnonlinearroboticsystems.f21.md
# Copied: _advanced_information_retrieval.md
# Copied: controltheorylinearcontrol.md
# Copied: _venture_capital_and_growth_hacking.md
# Copied: _advanced_statistics.md
# Copied: advanced_robotics.md
# Copied: offensivetechnologies.s22.md
# Copied: models_software_systems.md
# Copied: classicalinternetapplications.f21.md
# Copied: _optimization.md
# Copied: _advanced_security.md
# Copied: _machine_learning.md
# Copied: computationalintelligence.s22.md
# Copied: _requirements_engineering.md
# Copied: datamining.md
# Copied: inter_networking_and_routing.md
# Copied: securitysystemsnetworks.md
# Copied: managingsoftwaredevelopment.f21.md
# Copied: randomizedalgorithms.md
# Copied: advanced_security.md
# Copied: datamodelinganddatabases2.md
# Copied: highdimensionaldataanalysis.s22.md
# Copied: _inter_networking_and_routing.md
# Copied: _security_of_systems_and_networks.md
# Copied: managingsoftwaredevelopment%d1%8e.f21.md
# Copied: _founder_project.md
# Copied: internetworkingandrouting.md
# Copied: computer_vision.md
# Copied: modelssoftwaresystems.s22.md
# Copied: _large_systems.md
# Copied: classical_internet_applications.md
# Copied: _personal_software_process.md
# Copied: _secure_development.md
# Copied: dynamicsofnonlinearroboticsystems.md
# Copied: _syllabi_index.md
# Copied: advancedstatistics.s22.md
# Copied: requirements_engineering.md
# Copied: computational_intelligence.md
# Copied: advancedinformationretrieval.md
# Copied: architectures_software_systems.md
# Copied: _computer_vision.md
# Copied: advancednetworking.f21.md
# Copied: advancedrobotics.s22.md
# Copied: metricsandempiricalmethods.md
# Copied: unit-economicsforitstartups.md
# Copied: _communication.md
# Copied: analysis_software_artifacts.md
# Copied: oopandsoftwarearchitechture.md
# Copied: optimization.md
# Copied: communication.s22.md
# Copied: humanitarianelectives.md
# Copied: bigdatatechnologiesandanalytics.md
# Copied: _models_software_systems.md
# Copied: machinelearning.f21.md
# Copied: personalsoftwareprocess.md
# Copied: _analysis_software_artifacts.md
# Copied: _architectures_of_software_systems.md
# Copied: architecturessoftwaresystems.md
# Copied: largesystems.s22.md
# Copied: advancedsecurity.md
# Copied: bigdatatechnologiesandanalytics.f21.md
# Copied: gametheory.md
# Copied: cybercrime_forensics.md
# Copied: analysissoftwareartifacts.md
# Copied: advancedinformationretrieval.s22.md
# Copied: big_data_technologies_and_analytics.md
# Copied: syllabi_table.md
# Copied: architecturessoftwaresystems.s22.md
# Copied: _empirical_methods.md
# Copied: sensingperceptionactuation.f21.md
# Copied: analysissoftwareartifacts.s22.md
# Copied: communication.md
# Copied: advancedstatistics.md
# Copied: _managing_software_development.md
# Copied: advanced_statistics.md
# Copied: _fundamentals_of_robot_control.md
# Copied: classicalinternetapplications.md
# Copied: _advanced_machine_learning.md
# Copied: advanced_networking.md
# Copied: internetworkingandrouting.f21.md
# Copied: sensing_perception_actuation.md
# Copied: _it_product_development.md
# Copied: advancedmachinelearning.s22.md
# Copied: sensingperceptionactuation.md
# Copied: largeinstallationadministration.md
# Copied: computervision.md
# Copied: technicalelectives.md
# Copied: _advanced_robotics.md
# Copied: informationtheory.md
# Copied: _venture_and_growth_hacking.md
# Copied: advancednetworking.md
# Copied: _ceo_toolkit_strategy,_operations,_finance,_hr,_legal_aspects,_ip_law_and_innovations.md
# Copied: computationalintelligence.md
# Copied: advancedrobotics.md
# Copied: datasecurity.md
# Copied: empirical_methods.md
# Copied: _it_business_start.md
# Copied: advanced_information_retrieval.md
# Copied: advancedsecurity.s22.md
# Copied: _msc:_secure_development.md
# Copied: _sensing_perception_actuation.md
# Copied: managinsoftwaredevelopment_block1.md
# Copied: requirementsengineering.md
# Copied: _unit_economics_in_it_business.md
# Copied: empiricalmethods.f21.md
# Copied: architectures_of_software_systems.md
# Copied: distributedsystems.md
# Copied: personal_software_process.md
# Copied: offensivetechnologies.md
# Copied: probabilitystatistics.md
# Copied: large_systems.md
# Copied: managing_software_development.md
# Copied: _leadership_in_entrepreneurship.md
# Copied: offensive_technologies.md
# Copied: dynamics_of_non_linear_robotic_systems.md
# Copied: securityofsystemsandnetworks.md
# Copied: machine_learning.md
# Copied: fundamentalsofrobotcontrol.md
# Copied: advanced_machine_learning.md
# Copied: _offensive_technologies.md
# Copied: highdimensionaldataanalysis.md
# Copied: modelssoftwaresystems.md
# Copied: _cybercrime_forensics.md
# Copied: machinelearning.md
# Copied: computervision.s22.md
# Copied: unit-economics_for_it_startups.md
# Copied: cybercrimeforensics.md
# Copied: _dynamics_of_non_linear_robotic_systems.md
# Copied: _advanced_networking.md
# Copied: managinsoftwaredevelopment_block2.md
# Copied: researchmethods.md
# Copied: _marketing_and_sales_for_it_business.md
# Copied: cybercrimeforensics.s22.md
# Copied: _unit-economics_for_it_startups.md
# Copied: _high-dimensional_data_analysis.md
# Copied: requirementsengineering.f21.md
# Copied: _computational_intelligence.md
# Copied: managingsoftwaredevelopment.md
# Copied: _classical_internet_applications.md
# Copied: analyticalgeometryandlinearalgebrai.md
# Copied: behavioralandcognitiverobotics.md
# Copied: advancedmachinelearning.md
# Copied: personalsoftwareprocess.f21.md
# Copied: _big_data_technologies_and_analytics.md
# Copied: optimization.f21.md
# Copied: neuroscience.md
# Copied: _security_and_interpretability_of_machine_learning.md
# Copied: highperformancecomputing.md
# Copied: reinforcmentlearning.md
# Copied: _cross-platform_mobile_development_with_flutter.md
# Copied: introductiontofunctionalprogrammingandscalalanguage.md
# Copied: marketresearchforitstartups.md
# Copied: _art_of_reading_learning_and_understanding.md
# Copied: itproductdevelopment.md
# Copied: servicedesign.md
# Copied: _applied_machine_learning.md
# Copied: frontendwebdevelopment.md
# Copied: advancedtopicsinsoftwaretesting.md
# Copied: _distributed_systems.md
# Copied: _the_security_and_interpretability_of_machine_learning.md
# Copied: proceduralcontentgenerationforgames.md
# Copied: _advanced_linux.md
# Copied: introductiontopracticalartificialintelligence.md
# Copied: introductiontoquantumprogramming.md
# Copied: advancedcpp.md
# Copied: _computer_graphics_in_game_development.md
# Copied: distributedsystemsandmiddleware.md
# Copied: discretemathandlogic.md
# Copied: advanced_algorithms.md
# Copied: softwarearchitectures.md
# Copied: _probability_and_statistics.f23.md
# Copied: syllabi_index.md
# Copied: _academic_research_and_writing_culture_ii.md
# Copied: statisticaltechniquesfordatascience.s21.md
# Copied: practicalmachinelearningdeeplearning.md
# Copied: fundamentalsofcomputersecurity.md
# Copied: humanitieselectives.md
# Copied: academicresearchandwritingculture.md
# Copied: _capstone_project.md
# Copied: _differential_equations.f22.md
# Copied: _total_virtualization.md
# Copied: digitalsignalprocessing.md
# Copied: _software_quality,_reliability_and_security.md
# Copied: introductiontoprogramming.md
# Copied: datastructuresalgorithmsii.md
# Copied: softwarearchitectures.old.md
# Copied: _statistical_techniques_for_data_science.md
# Copied: networks.md
# Copied: networks.s22.md
# Copied: logic_and_discrete_mathematics.f21.md
# Copied: _game_theory.md
# Copied: naturallanguageprocessing.md
# Copied: _dev_ops_engineering.md
# Copied: _advanced_compilers_construction_and_program_analysis.md
# Copied: academicresearchandwritingculture2.s22.md
# Copied: distributedledgerstechnologies.md
# Copied: introductiontoprogramming.f21.md
# Copied: _compilers_construction.md
# Copied: softwaresystemsdesign.f21.md
# Copied: theoreticalcomputerscience.s22.md
# Copied: distributedandnetworkprogramming.f21.md
# Copied: _introduction_to_robotics.md
# Copied: _mechatronics.md
# Copied: _networks.md
# Copied: physicalcultureandsport.md
# Copied: _history.md
# Copied: _reinforcement_learning.md
# Copied: systemtheory.md
# Copied: sensorsandsensing.md
# Copied: datamining.md
# Copied: _analytic_geometry_and_linear_algebra_i.f22.md
# Copied: fundamentalsofgraphicsandvirtualrealities.md
# Copied: informationretrieval.md
# Copied: mathematicalanalysisi.f21.md
# Copied: devopsengineering.md
# Copied: _introduction_to_artificial_intelligence.md
# Copied: mathematicalmodeling.md
# Copied: _software_project.md
# Copied: nonlinearcontroltheory.md
# Copied: computerarchitecture.f21.md
# Copied: _physical_culture_and_sport_psychology.md
# Copied: systemandnetworkadministration.f21.md
# Copied: computerarchitecture.md
# Copied: roboticsystems.md
# Copied: _probability_and_statistics.f22.md
# Copied: _secure_system_development.md
# Copied: softwareverificationtesting.md
# Copied: compilersconstruction.s22.md
# Copied: analyticgeometryandlinearalgebrai.f21.md
# Copied: _introduction_to_programming_ii.md
# Copied: statisticaltechniquesfordatascience..md
# Copied: _human-ai_interaction_design.md
# Copied: _introduction_to_computer_vision.md
# Copied: embeddedandsharedmemoryprogramming.md
# Copied: _lean_software_development.md
# Copied: mathematicalanalysisii.f21.md
# Copied: history.f21.md
# Copied: datamining.s22.md
# Copied: phil1-introductiontologic.md
# Copied: introductiontoprogrammingi.old.md
# Copied: introductiontoprogrammingi.md
# Copied: logic_and_discrete_mathematics.md
# Copied: advanceddatabases.s22.md
# Copied: analyticgeometryandlinearalgebrai.md
# Copied: distributedsytemsandcloudcomputing.md
# Copied: _data_structures_algorithms.md
# Copied: numericalmodelling.md
# Copied: softwarequalityandreliability.md
# Copied: _distributed_and_network_programming.md
# Copied: _mathematical_analysis_ii.md
# Copied: securesystemdevelopment.md
# Copied: leansoftwaredevelopment.s22.md
# Copied: analyticgeometryandlinearalgebraii.md
# Copied: naturallanguageprocessing.s22.md
# Copied: englishforacademicpurposesii.s22.md
# Copied: history.md
# Copied: informationretrieval.s22.md
# Copied: controltheory.s22.md
# Copied: roboticsystems.s22.md
# Copied: _analytic_geometry_and_linear_algebra_ii.s23.md
# Copied: mathematicalanalysisii.s22.md
# Copied: microcontrollersandembeddedhardware.md
# Copied: physicsi.f21.md
# Copied: networkandcybersecurity.md
# Copied: _nature_inspired_computing.md
# Copied: datamodelingdatabasesii.md
# Copied: _introduction_to_big_data.md
# Copied: programmingparadigms.f21.md
# Copied: businessanalytics.md
# Copied: _theoretical_mechanics.md
# Copied: introductiontoartificialintelligence.md
# Copied: _practical_machine_learning_deep_learning.md
# Copied: _introduction_to_machine_learning.md
# Copied: .md
# Copied: _system_and_network_administration.md
# Copied: networkandcybersecurity.s22.md
# Copied: gametheory.md
# Copied: syllabi_table.md
# Copied: compilersconstruction.md
# Copied: _theoretical_computer_science.md
# Copied: _analytic_geometry_and_linear_algebra_ii.md
# Copied: englishforacademicpurposesi.md
# Copied: statisticaltechniquesfordatascience.s22.md
# Copied: academicresearchandwritingculture2.md
# Copied: _software_architectures.md
# Copied: mechatronics.md
# Copied: devopsengineering.f21.md
# Copied: _probability_and_statistics.md
# Copied: mobileapplicationdevelopment.md
# Copied: physicsi.md
# Copied: fundamentals.md
# Copied: _mathematical_analysis_i.f21.test.md
# Copied: _computer_architecture.md
# Copied: introductiontomachinelearning.md
# Copied: physicsii.md
# Copied: natureinspiredcomputing.md
# Copied: softwareproject.md
# Copied: mobileapplicationdevelopment-1.md
# Copied: advancedcompilersconstructionandprogramanalysis.md
# Copied: _mathematical_analysis_ii.s23.md
# Copied: _academic_research_and_writing_culture.md
# Copied: fundamentals_of_computer_security.md
# Copied: _operating_systems.md
# Copied: _analytic_geometry_and_linear_algebra_i.f21.md
# Copied: _introduction_to_programming.md
# Copied: mechanicsandmachines.s22.md
# Copied: _signals_and_systems.md
# Copied: introductiontorobotics.md
# Copied: _mathematical_analysis_i.md
# Copied: _it_product_development.md
# Copied: _analytic_geometry_and_linear_algebra_i.f23.md
# Copied: mathematicalanalysisii.md
# Copied: nonlinearoptimization.md
# Copied: _analytic_geometry_and_linear_algebra_i.md
# Copied: _mathematical_analysis_i.f22.md
# Copied: _advanced_databases.md
# Copied: signalsandsystems.md
# Copied: philosophyii.md
# Copied: _analytic_geometry_and_linear_algebra_ii.s22.md
# Copied: informationtheory.md
# Copied: humancomputerinterfaces.md
# Copied: physicsii.s22.md
# Copied: _control_theory.md
# Copied: introductiontocomputervision.f21.md
# Copied: theoreticalmechanics.md
# Copied: probabilityandstatistics.md
# Copied: leansoftwaredevelopment.md
# Copied: introductiontobigdata.md
# Copied: introductiontobigdata.f21.md
# Copied: _data_mining.md
# Copied: softwarequalityandreliability.s21.md
# Copied: controltheory.md
# Copied: programmingparadigms.md
# Copied: technicalelective.md
# Copied: _logic_and_discrete_mathematics.md
# Copied: _mathematical_analysis_i.f21.md
# Copied: mathematicalanalysisi.md
# Copied: introductiontomachinelearning.f21.md
# Copied: gametheory.s22.md
# Copied: _differential_equations.f23.md
# Copied: analyticalgeometryandlinearalgebrai-cs.md
# Copied: mathematicalanalysisii.s23.md
# Copied: advancedcompilerconstructionandprogramanalysis.md
# Copied: _differential_equations.md
# Copied: _network_and_cyber_security.md
# Copied: softwaresystemsdesign.md
# Copied: _mechanics_and_machines.md
# Copied: practicalmachinelearningdeeplearning.f21.md
# Copied: operatingsystems.f21.md
# Copied: _programming_paradigms.md
# Copied: introductiontocomputervision.md
# Copied: logicincomputerscience.md
# Copied: _physics_ii.md
# Copied: _advanced_linux.md
# Copied: _information_retrieval.md
# Copied: advancedalgorithms.md
# Copied: _robotic_systems.md
# Copied: introductiontoprogrammingii.s22.md
# Copied: _physics_i.md
# Copied: datastructuresalgorithms.md
# Copied: _introduction_to_optimization.f22.md
# Copied: _philosophy_ii.md
# Copied: sensorsandsensing.s22.md
# Copied: cloudcomputing.md
# Copied: project.md
# Copied: phil2-knowledgeandperception.md
# Copied: differentialequations.md
# Copied: physicalcultureandsport.s22.md
# Copied: logic_and_discrete_mathematics.f22.md
# Copied: introductiontoprogrammingii.md
# Copied: analyticgeometryandlinearalgebraii.s22.md
# Copied: _sensors_and_sensing.md
# Copied: introductiontoartificialintelligence.s22.md
# Copied: englishforacademicpurposesi.f21.md
# Copied: _introduction_to_artificial_intelligence.s22.md
# Copied: mechanicsandmachines.md
# Copied: operatingsystems.md
# Copied: _software_systems_design.md
# Copied: fundamentalsofsoftwareengineering.md
# Copied: datamodelingdatabasesi.md
# Copied: differentialequations.f21.md
# Copied: theoreticalcomputerscience.md
# Copied: philosophyi.f21.md
# Copied: englishforacademicpurposesii.md
# Copied: _fundamentals_of_computer_security.md
# Copied: probabilityandstatistics.f21.md
# Copied: theoreticalmechanics.f21.md
# Copied: statisticaltechniquesfordatascience.md
# Copied: systemandnetworkadministration.md
# Copied: principelsofcomputersecurity.md
# Copied: _natural_language_processing.md
# Copied: signalsandsystems.s22.md
# Copied: operatingsystems%d1%8e.f21.md
# Copied: _probability_and_statistics.s22.md
# Copied: distributedandnetworkprogramming.md
# Copied: introductiontorobotics.f21.md
# Copied: advanceddatabases.md
# Copied: philosophyii.f21.md
# Copied: _physical_culture_and_sport_nutrition.md
# Copied: syllabi_table_3%2b11.md
# Copied: mechatronics.f21.md
# Copied: syllabi_table_3%2b1.md
# Copied: advancedcompilersconstructionandprogramanalysis.s22.md
# Copied: _ceo_toolkit.md
# Copied: _mste:_it_course.md
# Copied: _market_research_for_it_startups.md
# Copied: _analysis_of_software_artifacts.md
# Copied: _introduction_to_programming.md
# Copied: _it_product_development.md
# Copied: _leadership_in_entrepreneurship.md
# Copied: _it_course.md
# Copied: academicresearchandwritingculture.md
# Copied: syllabi_table.md
# Copied: founderproject.md
# Copied: itproductdevelopment.md
# Copied: ceotoolkit:strategy,operations,finance,hr,legalaspects,iplawandinnovations.md
# Copied: schedule.md
# Copied: studyplan.md

# %% [markdown]
# Turn on logging

# %%
import logging
import sys


logging.basicConfig(stream=sys.stdout, level=logging.WARNING)
logging.getLogger().addHandler(logging.StreamHandler(stream=sys.stdout))

# %% [markdown]
# ## LlamaIndex

# %%
import chromadb
from llama_index import VectorStoreIndex, SimpleDirectoryReader, ServiceContext, StorageContext, load_index_from_storage
from llama_index.storage.storage_context import StorageContext

# %% [markdown]
# ### Load documents

# %%
docs_dir = "../data/raw"
documents = SimpleDirectoryReader(docs_dir).load_data()

# %%
persist_dir = "../storage"
db = chromadb.PersistentClient(path=persist_dir)

chroma_collection = db.get_or_create_collection("saira")

# %% [markdown]
# ### Create storage context

# %%
from llama_index.vector_stores import ChromaVectorStore


vector_store = ChromaVectorStore(chroma_collection=chroma_collection)

# %%
storage_context = StorageContext.from_defaults(
    vector_store=vector_store,
)

# %%
storage_context.persist(persist_dir=persist_dir)

# %% [markdown]
# ### Create service context

# %%
from llama_index.llms import Ollama


# llm_model = "llama2:13b"
llm_model = "mistral"
# llm_model = "yarn-mistral:7b-64k"
# llm_model = "orca2:13b"
llm = Ollama(model=llm_model)

# %%
from llama_index.embeddings import HuggingFaceEmbedding


# emb_model = "intfloat/multilingual-e5-large"
# emb_model = "intfloat/multilingual-e5-base"
emb_model = "intfloat/multilingual-e5-small"
embed_model = HuggingFaceEmbedding(model_name=emb_model)
# Out:
# [2023-11-24 22:12:33,443] [INFO] [real_accelerator.py:158:get_accelerator] Setting ds_accelerator to cuda (auto detect)

# %%
from llama_index.node_parser.file import SimpleFileNodeParser
# from llama_index.node_parser import SentenceSplitter


# node_parser = SimpleFileNodeParser()
# node_parser = SentenceSplitter(chunk_size=1024, chunk_overlap=20)

# %%
from llama_index import PromptHelper


# prompt_helper = PromptHelper(
    # context_window=4096,
    # num_output=256,
    # chunk_overlap_ratio=0.1,
    # chunk_size_limit=None,
# )

# %%
service_context = ServiceContext.from_defaults(
    llm=llm,
    embed_model='local',
    # embed_model=embed_model,
    # node_parser=node_parser,
    # prompt_helper=prompt_helper,
    chunk_size=1024,
    chunk_overlap=20
)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /home/user/vladimir/iu/SAIRA/notebooks/2.0-solution-rag.ipynb Cell 20 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22414553227d/home/user/vladimir/iu/SAIRA/notebooks/2.0-solution-rag.ipynb#Y116sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> service_context = ServiceContext.from_defaults(
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22414553227d/home/user/vladimir/iu/SAIRA/notebooks/2.0-solution-rag.ipynb#Y116sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     llm=llm,
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22414553227d/home/user/vladimir/iu/SAIRA/notebooks/2.0-solution-rag.ipynb#Y116sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>     embed_model='local',
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22414553227d/home/user/vladimir/iu/SAIRA/notebooks/2.0-solution-rag.ipynb#Y116sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>     # embed_model=embed_model,
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22414553227d/home/user/vladimir/iu/SAIRA/notebooks/2.0-solution-rag.ipynb#Y116sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>     # node_parser=node_parser,
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22414553227d/home/user/vladimir/iu/SAIRA/notebooks/2.0-solution-rag.ipynb#Y116sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>     # prompt_helper=prompt_helper,
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22414553227d/home/user/vladimir/iu/SAIRA/notebooks/2.0-solution-rag.ipynb#Y116sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>     chunk_size=1024,
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22414553227d/home/user/vladimir/iu/SAIRA/notebooks/2.0-solution-rag.ipynb#Y116sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a>     chunk_overlap=20
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22414553227d/home/user/vladimir/iu/SAIRA/notebooks/2.0-solution-rag.ipynb#Y116sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> )
#
# File ~/miniconda3/envs/vladimir-torch/lib/python3.10/site-packages/llama_index/service_context.py:173, in ServiceContext.from_defaults(cls, llm_predictor, llm, prompt_helper, embed_model, node_parser, text_splitter, transformations, llama_logger, callback_manager, system_prompt, query_wrapper_prompt, pydantic_program_mode, chunk_size, chunk_overlap, context_window, num_output, chunk_size_limit)
#     168         llm_predictor.query_wrapper_prompt = query_wrapper_prompt
#     170 # NOTE: the embed_model isn't used in all indices
#     171 # NOTE: embed model should be a transformation, but the way the service
#     172 # context works, we can't put in there yet.
# --> 173 embed_model = resolve_embed_model(embed_model)
#     174 embed_model.callback_manager = callback_manager
#     176 prompt_helper = prompt_helper or _get_default_prompt_helper(
#     177     llm_metadata=llm_predictor.metadata,
#     178     context_window=context_window,
#     179     num_output=num_output,
#     180 )
#
# File ~/miniconda3/envs/vladimir-torch/lib/python3.10/site-packages/llama_index/embeddings/utils.py:84, in resolve_embed_model(embed_model)
#      80         embed_model = InstructorEmbedding(
#      81             model_name=model_name, cache_folder=cache_folder
#      82         )
#      83     else:
# ---> 84         embed_model = HuggingFaceEmbedding(
#      85             model_name=model_name, cache_folder=cache_folder
#      86         )
#      88 if LCEmbeddings is not None and isinstance(embed_model, LCEmbeddings):
#      89     embed_model = LangchainEmbedding(embed_model)
#
# File ~/miniconda3/envs/vladimir-torch/lib/python3.10/site-packages/llama_index/embeddings/huggingface.py:87, in HuggingFaceEmbedding.__init__(self, model_name, tokenizer_name, pooling, max_length, query_instruction, text_instruction, normalize, model, tokenizer, embed_batch_size, cache_folder, trust_remote_code, device, callback_manager)
#      85 elif model_name is None:  # Extract model_name from model
#      86     model_name = model.name_or_path
# ---> 87 self._model = model.to(self._device)
#      89 if tokenizer is None:  # Use tokenizer_name with AutoTokenizer
#      90     tokenizer_name = (
#      91         model_name or tokenizer_name or DEFAULT_HUGGINGFACE_EMBEDDING_MODEL
#      92     )
#
# File ~/miniconda3/envs/vladimir-torch/lib/python3.10/site-packages/transformers/modeling_utils.py:2014, in PreTrainedModel.to(self, *args, **kwargs)
#    2009     raise ValueError(
#    2010         "`.to` is not supported for `4-bit` or `8-bit` bitsandbytes models. Please use the model as it is, since the"
#    2011         " model has already been set to the correct devices and casted to the correct `dtype`."
#    2012     )
#    2013 else:
# -> 2014     return super().to(*args, **kwargs)
#
# File ~/miniconda3/envs/vladimir-torch/lib/python3.10/site-packages/torch/nn/modules/module.py:1145, in Module.to(self, *args, **kwargs)
#    1141         return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1142                     non_blocking, memory_format=convert_to_format)
#    1143     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
# -> 1145 return self._apply(convert)
#
# File ~/miniconda3/envs/vladimir-torch/lib/python3.10/site-packages/torch/nn/modules/module.py:797, in Module._apply(self, fn)
#     795 def _apply(self, fn):
#     796     for module in self.children():
# --> 797         module._apply(fn)
#     799     def compute_should_use_set_data(tensor, tensor_applied):
#     800         if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     801             # If the new tensor has compatible tensor type as the existing tensor,
#     802             # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     807             # global flag to let the user control whether they want the future
#     808             # behavior of overwriting the existing tensor or not.
#
# File ~/miniconda3/envs/vladimir-torch/lib/python3.10/site-packages/torch/nn/modules/module.py:797, in Module._apply(self, fn)
#     795 def _apply(self, fn):
#     796     for module in self.children():
# --> 797         module._apply(fn)
#     799     def compute_should_use_set_data(tensor, tensor_applied):
#     800         if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     801             # If the new tensor has compatible tensor type as the existing tensor,
#     802             # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     807             # global flag to let the user control whether they want the future
#     808             # behavior of overwriting the existing tensor or not.
#
# File ~/miniconda3/envs/vladimir-torch/lib/python3.10/site-packages/torch/nn/modules/module.py:820, in Module._apply(self, fn)
#     816 # Tensors stored in modules are graph leaves, and we don't want to
#     817 # track autograd history of `param_applied`, so we have to use
#     818 # `with torch.no_grad():`
#     819 with torch.no_grad():
# --> 820     param_applied = fn(param)
#     821 should_use_set_data = compute_should_use_set_data(param, param_applied)
#     822 if should_use_set_data:
#
# File ~/miniconda3/envs/vladimir-torch/lib/python3.10/site-packages/torch/nn/modules/module.py:1143, in Module.to.<locals>.convert(t)
#    1140 if convert_to_format is not None and t.dim() in (4, 5):
#    1141     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1142                 non_blocking, memory_format=convert_to_format)
# -> 1143 return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %% [markdown]
# ### Create index

# %%
index = VectorStoreIndex.from_documents(
    documents, service_context=service_context, storage_context=storage_context
)
# Out:
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [32,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [33,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [34,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [35,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [36,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [37,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [38,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [39,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [40,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [41,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [42,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [43,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [44,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [45,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [46,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [47,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [48,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [49,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [50,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [51,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [52,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [53,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [54,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [55,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [56,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [57,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [58,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [59,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [60,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [61,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [62,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [63,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [64,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [65,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [66,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [67,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [68,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [69,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [70,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [71,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [72,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [73,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [74,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [75,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [76,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [77,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [78,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [79,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [80,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [81,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [82,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [83,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [84,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [85,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [86,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [87,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [88,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [89,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [90,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [91,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [92,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [93,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [94,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [95,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [96,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [97,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [98,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [99,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [100,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [101,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [102,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [103,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [104,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [105,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [106,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [107,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [108,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [109,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [110,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [111,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [112,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [113,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [114,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [115,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [116,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [117,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [118,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [119,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [120,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [121,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [122,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [123,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [124,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [125,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [126,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [127,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [0,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [1,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [2,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [3,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [4,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [5,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [6,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [7,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [8,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [9,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [10,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [11,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [12,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [13,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [14,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [15,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [16,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [17,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [18,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [19,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [20,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [21,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [22,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [23,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [24,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [25,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [26,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [27,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [28,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [29,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [30,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [682,0,0], thread: [31,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /home/user/vladimir/iu/SAIRA/notebooks/2.0-solution-rag.ipynb Cell 22 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22414553227d/home/user/vladimir/iu/SAIRA/notebooks/2.0-solution-rag.ipynb#Y121sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> index = VectorStoreIndex.from_documents(
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22414553227d/home/user/vladimir/iu/SAIRA/notebooks/2.0-solution-rag.ipynb#Y121sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     documents, service_context=service_context, storage_context=storage_context
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22414553227d/home/user/vladimir/iu/SAIRA/notebooks/2.0-solution-rag.ipynb#Y121sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> )
#
# File ~/miniconda3/envs/vladimir-torch/lib/python3.10/site-packages/llama_index/indices/base.py:106, in BaseIndex.from_documents(cls, documents, storage_context, service_context, show_progress, **kwargs)
#      97     docstore.set_document_hash(doc.get_doc_id(), doc.hash)
#      99 nodes = run_transformations(
#     100     documents,  # type: ignore
#     101     service_context.transformations,
#     102     show_progress=show_progress,
#     103     **kwargs,
#     104 )
# --> 106 return cls(
#     107     nodes=nodes,
#     108     storage_context=storage_context,
#     109     service_context=service_context,
#     110     show_progress=show_progress,
#     111     **kwargs,
#     112 )
#
# File ~/miniconda3/envs/vladimir-torch/lib/python3.10/site-packages/llama_index/indices/vector_store/base.py:49, in VectorStoreIndex.__init__(self, nodes, index_struct, service_context, storage_context, use_async, store_nodes_override, show_progress, **kwargs)
#      47 self._use_async = use_async
#      48 self._store_nodes_override = store_nodes_override
# ---> 49 super().__init__(
#      50     nodes=nodes,
#      51     index_struct=index_struct,
#      52     service_context=service_context,
#      53     storage_context=storage_context,
#      54     show_progress=show_progress,
#      55     **kwargs,
#      56 )
#
# File ~/miniconda3/envs/vladimir-torch/lib/python3.10/site-packages/llama_index/indices/base.py:71, in BaseIndex.__init__(self, nodes, index_struct, storage_context, service_context, show_progress, **kwargs)
#      69 if index_struct is None:
#      70     assert nodes is not None
# ---> 71     index_struct = self.build_index_from_nodes(nodes)
#      72 self._index_struct = index_struct
#      73 self._storage_context.index_store.add_index_struct(self._index_struct)
#
# File ~/miniconda3/envs/vladimir-torch/lib/python3.10/site-packages/llama_index/indices/vector_store/base.py:255, in VectorStoreIndex.build_index_from_nodes(self, nodes, **insert_kwargs)
#     244 def build_index_from_nodes(
#     245     self,
#     246     nodes: Sequence[BaseNode],
#     247     **insert_kwargs: Any,
#     248 ) -> IndexDict:
#     249     """Build the index from nodes.
#     250
#     251     NOTE: Overrides BaseIndex.build_index_from_nodes.
#     252         VectorStoreIndex only stores nodes in document store
#     253         if vector store does not store text
#     254     """
# --> 255     return self._build_index_from_nodes(nodes, **insert_kwargs)
#
# File ~/miniconda3/envs/vladimir-torch/lib/python3.10/site-packages/llama_index/indices/vector_store/base.py:236, in VectorStoreIndex._build_index_from_nodes(self, nodes, **insert_kwargs)
#     234     run_async_tasks(tasks)
#     235 else:
# --> 236     self._add_nodes_to_index(
#     237         index_struct,
#     238         nodes,
#     239         show_progress=self._show_progress,
#     240         **insert_kwargs,
#     241     )
#     242 return index_struct
#
# File ~/miniconda3/envs/vladimir-torch/lib/python3.10/site-packages/llama_index/indices/vector_store/base.py:189, in VectorStoreIndex._add_nodes_to_index(self, index_struct, nodes, show_progress, **insert_kwargs)
#     186 if not nodes:
#     187     return
# --> 189 nodes = self._get_node_with_embedding(nodes, show_progress)
#     190 new_ids = self._vector_store.add(nodes, **insert_kwargs)
#     192 if not self._vector_store.stores_text or self._store_nodes_override:
#     193     # NOTE: if the vector store doesn't store text,
#     194     # we need to add the nodes to the index struct and document store
#
# File ~/miniconda3/envs/vladimir-torch/lib/python3.10/site-packages/llama_index/indices/vector_store/base.py:101, in VectorStoreIndex._get_node_with_embedding(self, nodes, show_progress)
#      90 def _get_node_with_embedding(
#      91     self,
#      92     nodes: Sequence[BaseNode],
#      93     show_progress: bool = False,
#      94 ) -> List[BaseNode]:
#      95     """Get tuples of id, node, and embedding.
#      96
#      97     Allows us to store these nodes in a vector store.
#      98     Embeddings are called in batches.
#      99
#     100     """
# --> 101     id_to_embed_map = embed_nodes(
#     102         nodes, self._service_context.embed_model, show_progress=show_progress
#     103     )
#     105     results = []
#     106     for node in nodes:
#
# File ~/miniconda3/envs/vladimir-torch/lib/python3.10/site-packages/llama_index/indices/utils.py:137, in embed_nodes(nodes, embed_model, show_progress)
#     134     else:
#     135         id_to_embed_map[node.node_id] = node.embedding
# --> 137 new_embeddings = embed_model.get_text_embedding_batch(
#     138     texts_to_embed, show_progress=show_progress
#     139 )
#     141 for new_id, text_embedding in zip(ids_to_embed, new_embeddings):
#     142     id_to_embed_map[new_id] = text_embedding
#
# File ~/miniconda3/envs/vladimir-torch/lib/python3.10/site-packages/llama_index/embeddings/base.py:255, in BaseEmbedding.get_text_embedding_batch(self, texts, show_progress, **kwargs)
#     249 if idx == len(texts) - 1 or len(cur_batch) == self.embed_batch_size:
#     250     # flush
#     251     with self.callback_manager.event(
#     252         CBEventType.EMBEDDING,
#     253         payload={EventPayload.SERIALIZED: self.to_dict()},
#     254     ) as event:
# --> 255         embeddings = self._get_text_embeddings(cur_batch)
#     256         result_embeddings.extend(embeddings)
#     257         event.on_end(
#     258             payload={
#     259                 EventPayload.CHUNKS: cur_batch,
#     260                 EventPayload.EMBEDDINGS: embeddings,
#     261             },
#     262         )
#
# File ~/miniconda3/envs/vladimir-torch/lib/python3.10/site-packages/llama_index/embeddings/huggingface.py:199, in HuggingFaceEmbedding._get_text_embeddings(self, texts)
#     195 """Get text embeddings."""
#     196 texts = [
#     197     format_text(text, self.model_name, self.text_instruction) for text in texts
#     198 ]
# --> 199 return self._embed(texts)
#
# File ~/miniconda3/envs/vladimir-torch/lib/python3.10/site-packages/llama_index/embeddings/huggingface.py:158, in HuggingFaceEmbedding._embed(self, sentences)
#     153 # move tokenizer inputs to device
#     154 encoded_input = {
#     155     key: val.to(self._device) for key, val in encoded_input.items()
#     156 }
# --> 158 model_output = self._model(**encoded_input)
#     160 if self.pooling == Pooling.CLS:
#     161     context_layer: "torch.Tensor" = model_output[0]
#
# File ~/miniconda3/envs/vladimir-torch/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/envs/vladimir-torch/lib/python3.10/site-packages/transformers/models/xlm_roberta/modeling_xlm_roberta.py:846, in XLMRobertaModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     837 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#     839 embedding_output = self.embeddings(
#     840     input_ids=input_ids,
#     841     position_ids=position_ids,
#    (...)
#     844     past_key_values_length=past_key_values_length,
#     845 )
# --> 846 encoder_outputs = self.encoder(
#     847     embedding_output,
#     848     attention_mask=extended_attention_mask,
#     849     head_mask=head_mask,
#     850     encoder_hidden_states=encoder_hidden_states,
#     851     encoder_attention_mask=encoder_extended_attention_mask,
#     852     past_key_values=past_key_values,
#     853     use_cache=use_cache,
#     854     output_attentions=output_attentions,
#     855     output_hidden_states=output_hidden_states,
#     856     return_dict=return_dict,
#     857 )
#     858 sequence_output = encoder_outputs[0]
#     859 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File ~/miniconda3/envs/vladimir-torch/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/envs/vladimir-torch/lib/python3.10/site-packages/transformers/models/xlm_roberta/modeling_xlm_roberta.py:530, in XLMRobertaEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     521     layer_outputs = torch.utils.checkpoint.checkpoint(
#     522         create_custom_forward(layer_module),
#     523         hidden_states,
#    (...)
#     527         encoder_attention_mask,
#     528     )
#     529 else:
# --> 530     layer_outputs = layer_module(
#     531         hidden_states,
#     532         attention_mask,
#     533         layer_head_mask,
#     534         encoder_hidden_states,
#     535         encoder_attention_mask,
#     536         past_key_value,
#     537         output_attentions,
#     538     )
#     540 hidden_states = layer_outputs[0]
#     541 if use_cache:
#
# File ~/miniconda3/envs/vladimir-torch/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/envs/vladimir-torch/lib/python3.10/site-packages/transformers/models/xlm_roberta/modeling_xlm_roberta.py:414, in XLMRobertaLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     402 def forward(
#     403     self,
#     404     hidden_states: torch.Tensor,
#    (...)
#     411 ) -> Tuple[torch.Tensor]:
#     412     # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     413     self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 414     self_attention_outputs = self.attention(
#     415         hidden_states,
#     416         attention_mask,
#     417         head_mask,
#     418         output_attentions=output_attentions,
#     419         past_key_value=self_attn_past_key_value,
#     420     )
#     421     attention_output = self_attention_outputs[0]
#     423     # if decoder, the last output is tuple of self-attn cache
#
# File ~/miniconda3/envs/vladimir-torch/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/envs/vladimir-torch/lib/python3.10/site-packages/transformers/models/xlm_roberta/modeling_xlm_roberta.py:341, in XLMRobertaAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     331 def forward(
#     332     self,
#     333     hidden_states: torch.Tensor,
#    (...)
#     339     output_attentions: Optional[bool] = False,
#     340 ) -> Tuple[torch.Tensor]:
# --> 341     self_outputs = self.self(
#     342         hidden_states,
#     343         attention_mask,
#     344         head_mask,
#     345         encoder_hidden_states,
#     346         encoder_attention_mask,
#     347         past_key_value,
#     348         output_attentions,
#     349     )
#     350     attention_output = self.output(self_outputs[0], hidden_states)
#     351     outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#
# File ~/miniconda3/envs/vladimir-torch/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/envs/vladimir-torch/lib/python3.10/site-packages/transformers/models/xlm_roberta/modeling_xlm_roberta.py:220, in XLMRobertaSelfAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     218     value_layer = torch.cat([past_key_value[1], value_layer], dim=2)
#     219 else:
# --> 220     key_layer = self.transpose_for_scores(self.key(hidden_states))
#     221     value_layer = self.transpose_for_scores(self.value(hidden_states))
#     223 query_layer = self.transpose_for_scores(mixed_query_layer)
#
# File ~/miniconda3/envs/vladimir-torch/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/envs/vladimir-torch/lib/python3.10/site-packages/torch/nn/modules/linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: CUDA error: CUBLAS_STATUS_EXECUTION_FAILED when calling cublasLtMatmul with transpose_mat1 1 transpose_mat2 0 m 1024 n 5140 k 1024 mat1_ld 1024 mat2_ld 1024 result_ld 1024 abcType 0 computeType 68 scaleType 0

# %%
index_load = load_index_from_storage(storage_context, service_context=service_context)

# %% [markdown]
# ### Create query engine (retriever)

# %%
query_engine = index.as_query_engine(similarity_top_k=10, response_mode="tree_summarize", streaming=False)

# %%
query_engine_2 = index.as_query_engine()

# %%
from llama_index import (
    VectorStoreIndex,
    get_response_synthesizer,
)
from llama_index.retrievers import VectorIndexRetriever
from llama_index.query_engine import RetrieverQueryEngine
from llama_index.postprocessor import KeywordNodePostprocessor

retriever = VectorIndexRetriever(
    index=index,
    similarity_top_k=10,
)
node_postprocessors = [
    KeywordNodePostprocessor(
        required_keywords=["Combinator"], exclude_keywords=[
            "Based on the information provided", 
            "Without any prior knowledge",
            "Based on the information provided from the multiple sources",
            ""
            ]
    )
]

query_engine = RetrieverQueryEngine.from_args(
    retriever, node_postprocessors=node_postprocessors
)

# %% [markdown]
# ## Retrieve

# %%
response = query_engine.query("How to create a student club?")
print(response.response)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/user/vladimir/iu/SAIRA/notebooks/2.0-solution-rag.ipynb Cell 26 line 2
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22414553227d/home/user/vladimir/iu/SAIRA/notebooks/2.0-solution-rag.ipynb#Y125sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> response = query_engine.query("How to create a student club?")
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22414553227d/home/user/vladimir/iu/SAIRA/notebooks/2.0-solution-rag.ipynb#Y125sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> print(response.text)
#
# AttributeError: 'Response' object has no attribute 'text'

# %%
response = query_engine.query("What are Innopoints?")
print(response)
# Out:
#  Based on the information provided from multiple sources, there is no mention of "Innopoints" in any of the documents. Therefore, I cannot provide an answer to the query.

# %%
response = query_engine_2.query("What are innopoints?")
print(response)
# Out:
#  Based on the provided context, I'm afraid there is no mention of "innopoints" in any of the topics covered. The given context only discusses geometric shapes such as circles, ellipses, hyperbolas, parabolas, and vector equations related to these shapes.
#
# Therefore, it appears that "innopoints" is not a recognized term or concept in analytic geometry or linear algebra.

# %%
response = query_engine_2.query("How to create a student club?")
print(response)
# Out:
#   Sure! Based on the given context information, here is the answer to the query "How to create a student club?":
#
# To create a student club, you can click on the "Create my Club" button at campuslife.innopolis.ru/clubs. For questions or assistance, you can contact Evgeniia Dyuzhakova, the Student Clubs Advisor, by writing to her via email or social media (handle: @janedyuzha_dyuzha).
#
# Please note that creating a student club provides numerous benefits, such as self-awareness, soft skill development, networking opportunities, practical experience, and the ability to engage with diverse groups of people. Additionally, joining or starting a student club can be an enjoyable experience that contributes to university development and enhances your CV.

# %% [markdown]
# # Evaluation

# %%
import os
import json

def generate_answer(question, qe):
    response = qe.query(question)
    return response.response


def add_generated_field(json_data, qe):
    for item in json_data:
        question = item['question']
        generated_answer = generate_answer(question, qe)
        item['generated_answer'] = generated_answer
    return json_data

def add_generated_field_to_directory(input_directory, output_directory, qe):
    # Create the output directory if it doesn't exist
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)

    # Iterate through each JSON file in the input directory
    for filename in os.listdir(input_directory):
        if filename.endswith(".json"):
            input_filepath = os.path.join(input_directory, filename)
            output_filepath = os.path.join(output_directory, filename)

            # Load JSON data from the input file
            with open(input_filepath, 'r') as file:
                json_data = json.load(file)

            # Add the 'generated' field using the language model
            json_data_with_generated = add_generated_field(json_data, qe)

            # Save the updated JSON data to the output file
            with open(output_filepath, 'w') as output_file:
                json.dump(json_data_with_generated, output_file, indent=2)

# %%
input_directory = '../data/test'

# %%
output_directory = '../data/results/llama2-13b-emb-base-summarize'
add_generated_field_to_directory(input_directory, output_directory, query_engine)

# %%
output_directory = '../data/results/llama2-13b-emb-base-default'
add_generated_field_to_directory(input_directory, output_directory, query_engine_2)
