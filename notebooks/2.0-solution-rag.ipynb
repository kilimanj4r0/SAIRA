# %% [markdown]
# # Implementation of a solution using Retrieval Augmented Generation with LLM based on LlamaIndex framework

# %% [markdown]
# ### Data preparation
#
# Flatten all text files into raw folder

# %%
import os
import shutil


def copy_text_files(source_dir, destination_dir):
    # Create the destination directory if it doesn't exist
    if not os.path.exists(destination_dir):
        os.makedirs(destination_dir)

    # Traverse the source directory
    for root, dirs, files in os.walk(source_dir):
        for file in files:
            # Check if the file has a .txt extension (you can modify this condition)
            if file.endswith(".txt") or file.endswith(".md"):
                source_path = os.path.join(root, file)
                destination_path = os.path.join(destination_dir, 'raw_' + root.split('/')[-1] + '_' + file)

                # Copy the file to the destination directory
                shutil.copy2(source_path, destination_path)
                print(f"Copied: {file}")

# Replace 'source_directory' and 'destination_directory' with your actual paths
copy_text_files('../data/documents/', '../data/documents/raw')
copy_text_files('../data/documents/edu-wiki', '../data/documents/raw')
# Out:
# Copied: 11. Volunteering & Innopoints.md
# Copied: 2. Accommodation & Meal Plan.md
# Copied: 5. How to Order References?.md
# Copied: 12. Migration Control for International Students.md
# Copied: 9.5. Exchange Opportunities.md
# Copied: 13. Library.md
# Copied: 1. Academic Plan.md
# Copied: 9. Rules of registration for the military service:.md
# Copied: 8. Scholarships & Financial Support.md
# Copied: 10. Your Health.md
# Copied: Extracurricular.md
# Copied: Admin.md
# Copied: Academic.md
# Copied: Household.md
# Copied: apply.innopolis.university_master.txt
# Copied: apply.innopolis.university_grant.txt
# Copied: innopolis.university_sveden_apply.txt
# Copied: apply.innopolis.university_olymp-math.txt
# Copied: apply.innopolis.ru_get-in.txt
# Copied: apply.innopolis.university_olympiad-bonus.txt
# Copied: apply.innopolis.university_faq.txt
# Copied: career.innopolis.university.txt
# Copied: itproductdevelopment.md
# Copied: venturecapitalhacksfromzerotonegotiatinganinvestmentdeal.tex.md
# Copied: introductiontoitentrepreneurship.tex.md
# Copied: innovativeagilesoftwaredevelopmentmethodologyforhighreliabilityandmissioncriticalapplications.tex.md
# Copied: communicationforstartupsfrombootstaptoglobalmarkets.tex.md
# Copied: internationaltradeproceduresandregulations.tex.md
# Copied: leanstartupmethodology.tex.md
# Copied: formalsoftwaredevelopmentofandroidapps.tex.md
# Copied: softwareprojectmanagement.tex.md
# Copied: theprinciplesandpracticeofimportexport.tex.md
# Copied: bitcoinandcryptocurrencytechnologies.tex.md
# Copied: informationretrievalfordatascience.tex.md
# Copied: patternorienteddesign.tex.md
# Copied: fearlessideas.tex.md
# Copied: nocodeandlowcodedevelopment.md
# Copied: digitalsignalprocessing.tex.md
# Copied: negotiatingprocessesforthepromotionofcooperationandhumanrightsininternationalregimeshistory.tex.md
# Copied: proceduralcontentgenerationforgames.tex.md
# Copied: algorithmsofmachinelearning.tex.md
# Copied: humancomputerinteractiondesign.tex.md
# Copied: introductiontoconvexoptimization.tex.md
# Copied: introductiontocareerdevelopment.tex.md
# Copied: programminginhaskell.tex.md
# Copied: fundamentalsofinformationsecurity.tex.md
# Copied: industrialcpp.tex.md
# Copied: distributedsystemsandmiddlewarepatternsandframeworks.tex.md
# Copied: moderncppnewlanguageconceptsfeaturesandmechanisms.tex.md
# Copied: concurrentobjectorientedprogrammingwithscoop.tex.md
# Copied: functionalprogrammingandscalalanguage.tex.md
# Copied: industrialsoftwaretesting.tex.md
# Copied: userexperienceanduserinterfacedesignfundamentals.tex.md
# Copied: windowskernelarchitectureanddrivers.tex.md
# Copied: entrepreneurship.tex.md
# Copied: reverseengineering.tex.md
# Copied: productdesign.tex.md
# Copied: esportsindustrymarketingeconomyandgamedesign.tex.md
# Copied: digitalinnovationandentrepreneurship.tex.md
# Copied: frontendwebdevelopment.tex.md
# Copied: introductiontocommunication.tex.md
# Copied: practicalartificialintelligence.tex.md
# Copied: internationalbusinesslegalessentials.tex.md
# Copied: fundamentalsrobotcontrol.tex.md
# Copied: advancedalgorithmsforartificialintelligence.tex.md
# Copied: naturallanguageprocessingandmachinelearning.tex.md
# Copied: philosophyofinformation.tex.md
# Copied: decentralizedapplicationsonethereumplatform.tex.md
# Copied: advancedsoftwaredesign.tex.md
# Copied: economicsofentrepreneurship.tex.md
# Copied: industrialprogramminginjava.tex.md
# Copied: ethicsandit.tex.md
# Copied: thesis_guidelines.md
# Copied: what_if_i_failed.md
# Copied: mirkofarina.md
# Copied: vladimirivanov.md
# Copied: backups.md
# Copied: maratmingazov.md
# Copied: physical_culture_and_sport_exercise_physiology_mindfulness.md
# Copied: evgeniizouev.md
# Copied: newsboard.md
# Copied: the_guidelines_%26_faq_for_offering_elective_courses_at_innopolis_university.md
# Copied: adilkhan.md
# Copied: almaoracevic.md
# Copied: sergeygorodetsky.md
# Copied: main_page.md
# Copied: nikolaykudasov.md
# Copied: nikolayshilov.md
# Copied: georgygelvanovsky.md
# Copied: mansurkhazeev.md
# Copied: ms1and2.md
# Copied: faq_for_offering_an_elective.md
# Copied: information_page_about_study_process_in_moodle.md
# Copied: oksanazhirosh.md
# Copied: list_of_bsc_humanitarian_electives.md
# Copied: general_information.md
# Copied: kirillpoletkin.md
# Copied: scientific_sources_and_material.md
# Copied: electives.md
# Copied: professors.md
# Copied: igorgaponov.md
# Copied: exchange.md
# Copied: list_of_msc_technical_electives.md
# Copied: aleksandrmaloletov.md
# Copied: munirmakhmutov.md
# Copied: information_page_about_study_process.md
# Copied: newsboard,_channels_and_groups_links.md
# Copied: guzelfazlyeva.md
# Copied: list_of_all_courses.md
# Copied: yaroslavkholodov.md
# Copied: about_lecturing_a_course.md
# Copied: anastasiyapuzankova.md
# Copied: giancarlosucci.md
# Copied: alexandertormasov.md
# Copied: nursultanaskarbekuly.md
# Copied: evgeniyakruglova.md
# Copied: msccalendar.md
# Copied: ivankonyukhov.md
# Copied: ahsankazmi.md
# Copied: scientificsourcesandmaterial.md
# Copied: stanislavprotasov.md
# Copied: newcomer%27s.md
# Copied: employmentsupports.md
# Copied: how_to_moodle.md
# Copied: alexanderklimchik.md
# Copied: artemkruglov.md
# Copied: thesisguidelines.md
# Copied: technical_electives.md
# Copied: andreyfrolov.md
# Copied: sergeysavin.md
# Copied: josephbrown.md
# Copied: semenkurkin.md
# Copied: winter_school.md
# Copied: humanitarian_electives.md
# Copied: ruslansaduov.md
# Copied: manuelmazzara.md
# Copied: rasheedhussain.md
# Copied: phd.md
# Copied: overallregulations.md
# Copied: professor_information_page.md
# Copied: olegkiselev.md
# Copied: luizaraujo.md
# Copied: howtomoodle.md
# Copied: innopolisuniversitymanifestoonmedium.md
# Copied: whatififailed.md
# Copied: exchange_program_%26_summer_school.md
# Copied: faqinstructors.md
# Copied: academicleave.md
# Copied: saifmohammedsabri.md
# Copied: the_guidelines_%26_faq_for_offering_elective_courses.md
# Copied: nursultan_askarbekuly.md
# Copied: educational_opportunities_for_alumni.md
# Copied: rababmarouf.md
# Copied: bscphysicalcultureandsportexercisephysiologymindfulness.md
# Copied: list_of_electives.md
# Copied: academic_leave.md
# Copied: employment_supports_and_educational_opportunities_for_alumni.md
# Copied: mohammedrezabahrami.md
# Copied: paolociancarini.md
# Copied: faqstudents.md
# Copied: olegbulichev.md
# Copied: howtomoodlerus.md
# Copied: summer_school.md
# Copied: professorinformationpage.md
# Copied: about_this_document.md
# Copied: list_of_core_courses.md
# Copied: list_of_msc_humanitarian_electives.md
# Copied: structure_of_the_bs_degrees.md
# Copied: employment_supports.md
# Copied: faqforofferingelective.md
# Copied: kirillsaltanov.md
# Copied: list_of_bsc_technical_electives.md
# Copied: listofpublications.md
# Copied: academiccalendar.md
# Copied: exchange_program.md
# Copied: studentinformationpage.md
# Copied: artemburmyakov.md
# Copied: andreysadovykh.md
# Copied: itproductdevelopment.md
# Copied: _fundraising,_go_to_market_and_hyper_growth_for_startups.md
# Copied: designfiction.md
# Copied: _human_and_animal_brain_representation_in_neurosciences.md
# Copied: techstartudesign.md
# Copied: _introduction_to_it_entrepreneurship.md
# Copied: scienceethics.md
# Copied: introductiontoitentrepreneurship.md
# Copied: _leadership_in_entrepreneurship.md
# Copied: _career_and_leadership.md
# Copied: _developing_entrepreneurial_skills_for_a_startup_founder.md
# Copied: introductiontocareerdevelopment.md
# Copied: venture_capital_hacks_in_it_industry:_from_zero_to_negotiating_and_investment_deal.md
# Copied: introductiontoeconomicsofentrepreneurship.md
# Copied: venturecapitalhacksinitindustry.md
# Copied: _it_product_development.md
# Copied: empiricalmethods.md
# Copied: syllabi_index.md
# Copied: high-dimensional_data_analysis.md
# Copied: dynamicsofnonlinearroboticsystems.f21.md
# Copied: _advanced_information_retrieval.md
# Copied: controltheorylinearcontrol.md
# Copied: _venture_capital_and_growth_hacking.md
# Copied: _advanced_statistics.md
# Copied: advanced_robotics.md
# Copied: offensivetechnologies.s22.md
# Copied: models_software_systems.md
# Copied: classicalinternetapplications.f21.md
# Copied: _optimization.md
# Copied: _advanced_security.md
# Copied: _machine_learning.md
# Copied: computationalintelligence.s22.md
# Copied: _requirements_engineering.md
# Copied: datamining.md
# Copied: inter_networking_and_routing.md
# Copied: securitysystemsnetworks.md
# Copied: managingsoftwaredevelopment.f21.md
# Copied: randomizedalgorithms.md
# Copied: advanced_security.md
# Copied: datamodelinganddatabases2.md
# Copied: highdimensionaldataanalysis.s22.md
# Copied: _inter_networking_and_routing.md
# Copied: _security_of_systems_and_networks.md
# Copied: managingsoftwaredevelopment%d1%8e.f21.md
# Copied: _founder_project.md
# Copied: internetworkingandrouting.md
# Copied: computer_vision.md
# Copied: modelssoftwaresystems.s22.md
# Copied: _large_systems.md
# Copied: classical_internet_applications.md
# Copied: _personal_software_process.md
# Copied: _secure_development.md
# Copied: dynamicsofnonlinearroboticsystems.md
# Copied: _syllabi_index.md
# Copied: advancedstatistics.s22.md
# Copied: requirements_engineering.md
# Copied: computational_intelligence.md
# Copied: advancedinformationretrieval.md
# Copied: architectures_software_systems.md
# Copied: _computer_vision.md
# Copied: advancednetworking.f21.md
# Copied: advancedrobotics.s22.md
# Copied: metricsandempiricalmethods.md
# Copied: unit-economicsforitstartups.md
# Copied: _communication.md
# Copied: analysis_software_artifacts.md
# Copied: oopandsoftwarearchitechture.md
# Copied: optimization.md
# Copied: communication.s22.md
# Copied: humanitarianelectives.md
# Copied: bigdatatechnologiesandanalytics.md
# Copied: _models_software_systems.md
# Copied: machinelearning.f21.md
# Copied: personalsoftwareprocess.md
# Copied: _analysis_software_artifacts.md
# Copied: _architectures_of_software_systems.md
# Copied: architecturessoftwaresystems.md
# Copied: largesystems.s22.md
# Copied: advancedsecurity.md
# Copied: bigdatatechnologiesandanalytics.f21.md
# Copied: gametheory.md
# Copied: cybercrime_forensics.md
# Copied: analysissoftwareartifacts.md
# Copied: advancedinformationretrieval.s22.md
# Copied: big_data_technologies_and_analytics.md
# Copied: syllabi_table.md
# Copied: architecturessoftwaresystems.s22.md
# Copied: _empirical_methods.md
# Copied: sensingperceptionactuation.f21.md
# Copied: analysissoftwareartifacts.s22.md
# Copied: communication.md
# Copied: advancedstatistics.md
# Copied: _managing_software_development.md
# Copied: advanced_statistics.md
# Copied: _fundamentals_of_robot_control.md
# Copied: classicalinternetapplications.md
# Copied: _advanced_machine_learning.md
# Copied: advanced_networking.md
# Copied: internetworkingandrouting.f21.md
# Copied: sensing_perception_actuation.md
# Copied: _it_product_development.md
# Copied: advancedmachinelearning.s22.md
# Copied: sensingperceptionactuation.md
# Copied: largeinstallationadministration.md
# Copied: computervision.md
# Copied: technicalelectives.md
# Copied: _advanced_robotics.md
# Copied: informationtheory.md
# Copied: _venture_and_growth_hacking.md
# Copied: advancednetworking.md
# Copied: _ceo_toolkit_strategy,_operations,_finance,_hr,_legal_aspects,_ip_law_and_innovations.md
# Copied: computationalintelligence.md
# Copied: advancedrobotics.md
# Copied: datasecurity.md
# Copied: empirical_methods.md
# Copied: _it_business_start.md
# Copied: advanced_information_retrieval.md
# Copied: advancedsecurity.s22.md
# Copied: _msc:_secure_development.md
# Copied: _sensing_perception_actuation.md
# Copied: managinsoftwaredevelopment_block1.md
# Copied: requirementsengineering.md
# Copied: _unit_economics_in_it_business.md
# Copied: empiricalmethods.f21.md
# Copied: architectures_of_software_systems.md
# Copied: distributedsystems.md
# Copied: personal_software_process.md
# Copied: offensivetechnologies.md
# Copied: probabilitystatistics.md
# Copied: large_systems.md
# Copied: managing_software_development.md
# Copied: _leadership_in_entrepreneurship.md
# Copied: offensive_technologies.md
# Copied: dynamics_of_non_linear_robotic_systems.md
# Copied: securityofsystemsandnetworks.md
# Copied: machine_learning.md
# Copied: fundamentalsofrobotcontrol.md
# Copied: advanced_machine_learning.md
# Copied: _offensive_technologies.md
# Copied: highdimensionaldataanalysis.md
# Copied: modelssoftwaresystems.md
# Copied: _cybercrime_forensics.md
# Copied: machinelearning.md
# Copied: computervision.s22.md
# Copied: unit-economics_for_it_startups.md
# Copied: cybercrimeforensics.md
# Copied: _dynamics_of_non_linear_robotic_systems.md
# Copied: _advanced_networking.md
# Copied: managinsoftwaredevelopment_block2.md
# Copied: researchmethods.md
# Copied: _marketing_and_sales_for_it_business.md
# Copied: cybercrimeforensics.s22.md
# Copied: _unit-economics_for_it_startups.md
# Copied: _high-dimensional_data_analysis.md
# Copied: requirementsengineering.f21.md
# Copied: _computational_intelligence.md
# Copied: managingsoftwaredevelopment.md
# Copied: _classical_internet_applications.md
# Copied: analyticalgeometryandlinearalgebrai.md
# Copied: behavioralandcognitiverobotics.md
# Copied: advancedmachinelearning.md
# Copied: personalsoftwareprocess.f21.md
# Copied: _big_data_technologies_and_analytics.md
# Copied: optimization.f21.md
# Copied: neuroscience.md
# Copied: _security_and_interpretability_of_machine_learning.md
# Copied: highperformancecomputing.md
# Copied: reinforcmentlearning.md
# Copied: _cross-platform_mobile_development_with_flutter.md
# Copied: introductiontofunctionalprogrammingandscalalanguage.md
# Copied: marketresearchforitstartups.md
# Copied: _art_of_reading_learning_and_understanding.md
# Copied: itproductdevelopment.md
# Copied: servicedesign.md
# Copied: _applied_machine_learning.md
# Copied: frontendwebdevelopment.md
# Copied: advancedtopicsinsoftwaretesting.md
# Copied: _distributed_systems.md
# Copied: _the_security_and_interpretability_of_machine_learning.md
# Copied: proceduralcontentgenerationforgames.md
# Copied: _advanced_linux.md
# Copied: introductiontopracticalartificialintelligence.md
# Copied: introductiontoquantumprogramming.md
# Copied: advancedcpp.md
# Copied: _computer_graphics_in_game_development.md
# Copied: distributedsystemsandmiddleware.md
# Copied: discretemathandlogic.md
# Copied: advanced_algorithms.md
# Copied: softwarearchitectures.md
# Copied: _probability_and_statistics.f23.md
# Copied: syllabi_index.md
# Copied: _academic_research_and_writing_culture_ii.md
# Copied: statisticaltechniquesfordatascience.s21.md
# Copied: practicalmachinelearningdeeplearning.md
# Copied: fundamentalsofcomputersecurity.md
# Copied: humanitieselectives.md
# Copied: academicresearchandwritingculture.md
# Copied: _capstone_project.md
# Copied: _differential_equations.f22.md
# Copied: _total_virtualization.md
# Copied: digitalsignalprocessing.md
# Copied: _software_quality,_reliability_and_security.md
# Copied: introductiontoprogramming.md
# Copied: datastructuresalgorithmsii.md
# Copied: softwarearchitectures.old.md
# Copied: _statistical_techniques_for_data_science.md
# Copied: networks.md
# Copied: networks.s22.md
# Copied: logic_and_discrete_mathematics.f21.md
# Copied: _game_theory.md
# Copied: naturallanguageprocessing.md
# Copied: _dev_ops_engineering.md
# Copied: _advanced_compilers_construction_and_program_analysis.md
# Copied: academicresearchandwritingculture2.s22.md
# Copied: distributedledgerstechnologies.md
# Copied: introductiontoprogramming.f21.md
# Copied: _compilers_construction.md
# Copied: softwaresystemsdesign.f21.md
# Copied: theoreticalcomputerscience.s22.md
# Copied: distributedandnetworkprogramming.f21.md
# Copied: _introduction_to_robotics.md
# Copied: _mechatronics.md
# Copied: _networks.md
# Copied: physicalcultureandsport.md
# Copied: _history.md
# Copied: _reinforcement_learning.md
# Copied: systemtheory.md
# Copied: sensorsandsensing.md
# Copied: datamining.md
# Copied: _analytic_geometry_and_linear_algebra_i.f22.md
# Copied: fundamentalsofgraphicsandvirtualrealities.md
# Copied: informationretrieval.md
# Copied: mathematicalanalysisi.f21.md
# Copied: devopsengineering.md
# Copied: _introduction_to_artificial_intelligence.md
# Copied: mathematicalmodeling.md
# Copied: _software_project.md
# Copied: nonlinearcontroltheory.md
# Copied: computerarchitecture.f21.md
# Copied: _physical_culture_and_sport_psychology.md
# Copied: systemandnetworkadministration.f21.md
# Copied: computerarchitecture.md
# Copied: roboticsystems.md
# Copied: _probability_and_statistics.f22.md
# Copied: _secure_system_development.md
# Copied: softwareverificationtesting.md
# Copied: compilersconstruction.s22.md
# Copied: analyticgeometryandlinearalgebrai.f21.md
# Copied: _introduction_to_programming_ii.md
# Copied: statisticaltechniquesfordatascience..md
# Copied: _human-ai_interaction_design.md
# Copied: _introduction_to_computer_vision.md
# Copied: embeddedandsharedmemoryprogramming.md
# Copied: _lean_software_development.md
# Copied: mathematicalanalysisii.f21.md
# Copied: history.f21.md
# Copied: datamining.s22.md
# Copied: phil1-introductiontologic.md
# Copied: introductiontoprogrammingi.old.md
# Copied: introductiontoprogrammingi.md
# Copied: logic_and_discrete_mathematics.md
# Copied: advanceddatabases.s22.md
# Copied: analyticgeometryandlinearalgebrai.md
# Copied: distributedsytemsandcloudcomputing.md
# Copied: _data_structures_algorithms.md
# Copied: numericalmodelling.md
# Copied: softwarequalityandreliability.md
# Copied: _distributed_and_network_programming.md
# Copied: _mathematical_analysis_ii.md
# Copied: securesystemdevelopment.md
# Copied: leansoftwaredevelopment.s22.md
# Copied: analyticgeometryandlinearalgebraii.md
# Copied: naturallanguageprocessing.s22.md
# Copied: englishforacademicpurposesii.s22.md
# Copied: history.md
# Copied: informationretrieval.s22.md
# Copied: controltheory.s22.md
# Copied: roboticsystems.s22.md
# Copied: _analytic_geometry_and_linear_algebra_ii.s23.md
# Copied: mathematicalanalysisii.s22.md
# Copied: microcontrollersandembeddedhardware.md
# Copied: physicsi.f21.md
# Copied: networkandcybersecurity.md
# Copied: _nature_inspired_computing.md
# Copied: datamodelingdatabasesii.md
# Copied: _introduction_to_big_data.md
# Copied: programmingparadigms.f21.md
# Copied: businessanalytics.md
# Copied: _theoretical_mechanics.md
# Copied: introductiontoartificialintelligence.md
# Copied: _practical_machine_learning_deep_learning.md
# Copied: _introduction_to_machine_learning.md
# Copied: .md
# Copied: _system_and_network_administration.md
# Copied: networkandcybersecurity.s22.md
# Copied: gametheory.md
# Copied: syllabi_table.md
# Copied: compilersconstruction.md
# Copied: _theoretical_computer_science.md
# Copied: _analytic_geometry_and_linear_algebra_ii.md
# Copied: englishforacademicpurposesi.md
# Copied: statisticaltechniquesfordatascience.s22.md
# Copied: academicresearchandwritingculture2.md
# Copied: _software_architectures.md
# Copied: mechatronics.md
# Copied: devopsengineering.f21.md
# Copied: _probability_and_statistics.md
# Copied: mobileapplicationdevelopment.md
# Copied: physicsi.md
# Copied: fundamentals.md
# Copied: _mathematical_analysis_i.f21.test.md
# Copied: _computer_architecture.md
# Copied: introductiontomachinelearning.md
# Copied: physicsii.md
# Copied: natureinspiredcomputing.md
# Copied: softwareproject.md
# Copied: mobileapplicationdevelopment-1.md
# Copied: advancedcompilersconstructionandprogramanalysis.md
# Copied: _mathematical_analysis_ii.s23.md
# Copied: _academic_research_and_writing_culture.md
# Copied: fundamentals_of_computer_security.md
# Copied: _operating_systems.md
# Copied: _analytic_geometry_and_linear_algebra_i.f21.md
# Copied: _introduction_to_programming.md
# Copied: mechanicsandmachines.s22.md
# Copied: _signals_and_systems.md
# Copied: introductiontorobotics.md
# Copied: _mathematical_analysis_i.md
# Copied: _it_product_development.md
# Copied: _analytic_geometry_and_linear_algebra_i.f23.md
# Copied: mathematicalanalysisii.md
# Copied: nonlinearoptimization.md
# Copied: _analytic_geometry_and_linear_algebra_i.md
# Copied: _mathematical_analysis_i.f22.md
# Copied: _advanced_databases.md
# Copied: signalsandsystems.md
# Copied: philosophyii.md
# Copied: _analytic_geometry_and_linear_algebra_ii.s22.md
# Copied: informationtheory.md
# Copied: humancomputerinterfaces.md
# Copied: physicsii.s22.md
# Copied: _control_theory.md
# Copied: introductiontocomputervision.f21.md
# Copied: theoreticalmechanics.md
# Copied: probabilityandstatistics.md
# Copied: leansoftwaredevelopment.md
# Copied: introductiontobigdata.md
# Copied: introductiontobigdata.f21.md
# Copied: _data_mining.md
# Copied: softwarequalityandreliability.s21.md
# Copied: controltheory.md
# Copied: programmingparadigms.md
# Copied: technicalelective.md
# Copied: _logic_and_discrete_mathematics.md
# Copied: _mathematical_analysis_i.f21.md
# Copied: mathematicalanalysisi.md
# Copied: introductiontomachinelearning.f21.md
# Copied: gametheory.s22.md
# Copied: _differential_equations.f23.md
# Copied: analyticalgeometryandlinearalgebrai-cs.md
# Copied: mathematicalanalysisii.s23.md
# Copied: advancedcompilerconstructionandprogramanalysis.md
# Copied: _differential_equations.md
# Copied: _network_and_cyber_security.md
# Copied: softwaresystemsdesign.md
# Copied: _mechanics_and_machines.md
# Copied: practicalmachinelearningdeeplearning.f21.md
# Copied: operatingsystems.f21.md
# Copied: _programming_paradigms.md
# Copied: introductiontocomputervision.md
# Copied: logicincomputerscience.md
# Copied: _physics_ii.md
# Copied: _advanced_linux.md
# Copied: _information_retrieval.md
# Copied: advancedalgorithms.md
# Copied: _robotic_systems.md
# Copied: introductiontoprogrammingii.s22.md
# Copied: _physics_i.md
# Copied: datastructuresalgorithms.md
# Copied: _introduction_to_optimization.f22.md
# Copied: _philosophy_ii.md
# Copied: sensorsandsensing.s22.md
# Copied: cloudcomputing.md
# Copied: project.md
# Copied: phil2-knowledgeandperception.md
# Copied: differentialequations.md
# Copied: physicalcultureandsport.s22.md
# Copied: logic_and_discrete_mathematics.f22.md
# Copied: introductiontoprogrammingii.md
# Copied: analyticgeometryandlinearalgebraii.s22.md
# Copied: _sensors_and_sensing.md
# Copied: introductiontoartificialintelligence.s22.md
# Copied: englishforacademicpurposesi.f21.md
# Copied: _introduction_to_artificial_intelligence.s22.md
# Copied: mechanicsandmachines.md
# Copied: operatingsystems.md
# Copied: _software_systems_design.md
# Copied: fundamentalsofsoftwareengineering.md
# Copied: datamodelingdatabasesi.md
# Copied: differentialequations.f21.md
# Copied: theoreticalcomputerscience.md
# Copied: philosophyi.f21.md
# Copied: englishforacademicpurposesii.md
# Copied: _fundamentals_of_computer_security.md
# Copied: probabilityandstatistics.f21.md
# Copied: theoreticalmechanics.f21.md
# Copied: statisticaltechniquesfordatascience.md
# Copied: systemandnetworkadministration.md
# Copied: principelsofcomputersecurity.md
# Copied: _natural_language_processing.md
# Copied: signalsandsystems.s22.md
# Copied: operatingsystems%d1%8e.f21.md
# Copied: _probability_and_statistics.s22.md
# Copied: distributedandnetworkprogramming.md
# Copied: introductiontorobotics.f21.md
# Copied: advanceddatabases.md
# Copied: philosophyii.f21.md
# Copied: _physical_culture_and_sport_nutrition.md
# Copied: syllabi_table_3%2b11.md
# Copied: mechatronics.f21.md
# Copied: syllabi_table_3%2b1.md
# Copied: advancedcompilersconstructionandprogramanalysis.s22.md
# Copied: _ceo_toolkit.md
# Copied: _mste:_it_course.md
# Copied: _market_research_for_it_startups.md
# Copied: _analysis_of_software_artifacts.md
# Copied: _introduction_to_programming.md
# Copied: _it_product_development.md
# Copied: _leadership_in_entrepreneurship.md
# Copied: _it_course.md
# Copied: academicresearchandwritingculture.md
# Copied: syllabi_table.md
# Copied: founderproject.md
# Copied: itproductdevelopment.md
# Copied: ceotoolkit:strategy,operations,finance,hr,legalaspects,iplawandinnovations.md
# Copied: schedule.md
# Copied: studyplan.md
# Copied: Tech clubs.md
# Copied: Art clubs.md
# Copied: Sport clubs.md
# Copied: Special interest clubs.md
# Copied: clubs.md
# Copied: raw_raw_raw_msc_advancedrobotics.md
# Copied: raw_bsc_operatingsystems.f21.md
# Copied: raw_msc_classicalinternetapplications.md
# Copied: raw_bsc_digitalsignalprocessing.md
# Copied: raw_msc_analyticalgeometryandlinearalgebrai.md
# Copied: raw_msc_inter_networking_and_routing.md
# Copied: raw_bsc_mathematicalanalysisii.f21.md
# Copied: raw_bsc_analyticgeometryandlinearalgebraii.md
# Copied: raw_others_what_if_i_failed.md
# Copied: raw_raw_raw_bste_introductiontoquantumprogramming.md
# Copied: raw_elective_internationaltradeproceduresandregulations.tex.md
# Copied: raw_raw_raw_others_professor_information_page.md
# Copied: raw_bsc__probability_and_statistics.md
# Copied: raw_raw_raw_bsc_academicresearchandwritingculture2.md
# Copied: raw_bsc_introductiontoprogrammingi.old.md
# Copied: raw_bsc_compilersconstruction.md
# Copied: raw_msc_advancedmachinelearning.md
# Copied: raw_bshe__introduction_to_it_entrepreneurship.md
# Copied: raw_raw_raw_msc__classical_internet_applications.md
# Copied: raw_raw_raw_msc_machine_learning.md
# Copied: raw_raw_raw_msc__venture_and_growth_hacking.md
# Copied: raw_raw_raw_bsc_mathematicalanalysisii.s22.md
# Copied: raw_bste_highperformancecomputing.md
# Copied: raw_raw_raw_others_what_if_i_failed.md
# Copied: raw_raw_raw_bsc_mechatronics.md
# Copied: raw_raw_raw_mste__analysis_of_software_artifacts.md
# Copied: raw_bshe_introductiontoeconomicsofentrepreneurship.md
# Copied: raw_raw_raw_clubs_clubs.md
# Copied: raw_raw_raw_others_thesisguidelines.md
# Copied: raw_raw_raw_elective_humancomputerinteractiondesign.tex.md
# Copied: raw_faq_Extracurricular.md
# Copied: raw_raw_raw_bste_highperformancecomputing.md
# Copied: raw_raw_raw_bsc_discretemathandlogic.md
# Copied: raw_raw_raw_others_kirillsaltanov.md
# Copied: raw_bsc_introductiontorobotics.md
# Copied: raw_raw_raw_msc_architectures_software_systems.md
# Copied: raw_msc_datasecurity.md
# Copied: raw_raw_raw_bsc_theoreticalmechanics.f21.md
# Copied: raw_raw_raw_bsc_probabilityandstatistics.f21.md
# Copied: raw_msc_dynamicsofnonlinearroboticsystems.f21.md
# Copied: raw_msc__computer_vision.md
# Copied: raw_raw_raw_bsc_mobileapplicationdevelopment-1.md
# Copied: raw_bsc_logic_and_discrete_mathematics.f22.md
# Copied: raw_raw_raw_elective_theprinciplesandpracticeofimportexport.tex.md
# Copied: raw_raw_raw_elective_esportsindustrymarketingeconomyandgamedesign.tex.md
# Copied: raw_raw_raw_msc_computational_intelligence.md
# Copied: raw_elective_functionalprogrammingandscalalanguage.tex.md
# Copied: raw_elective_algorithmsofmachinelearning.tex.md
# Copied: raw_msc__personal_software_process.md
# Copied: raw_bsc_naturallanguageprocessing.s22.md
# Copied: raw_raw_raw_mste__introduction_to_programming.md
# Copied: raw_bshe__developing_entrepreneurial_skills_for_a_startup_founder.md
# Copied: raw_raw_raw_handbook_10. Your Health.md
# Copied: raw_raw_raw_others_mansurkhazeev.md
# Copied: raw_others_mirkofarina.md
# Copied: raw_raw_raw_bsc__capstone_project.md
# Copied: raw_raw_raw_bshe__developing_entrepreneurial_skills_for_a_startup_founder.md
# Copied: raw_raw_raw_bsc_fundamentalsofsoftwareengineering.md
# Copied: raw_others_scientificsourcesandmaterial.md
# Copied: raw_raw_raw_bsc_nonlinearcontroltheory.md
# Copied: raw_raw_raw_bsc__probability_and_statistics.s22.md
# Copied: raw_raw_raw_bste__cross-platform_mobile_development_with_flutter.md
# Copied: raw_raw_raw_elective_practicalartificialintelligence.tex.md
# Copied: raw_raw_raw_msc__models_software_systems.md
# Copied: raw_raw_raw_bste_advancedcpp.md
# Copied: raw_raw_raw_others_yaroslavkholodov.md
# Copied: raw_raw_raw_elective_algorithmsofmachinelearning.tex.md
# Copied: raw_raw_raw_bste_proceduralcontentgenerationforgames.md
# Copied: raw_others_faqinstructors.md
# Copied: raw_raw_raw_bshe__career_and_leadership.md
# Copied: raw_elective_productdesign.tex.md
# Copied: raw_msc__requirements_engineering.md
# Copied: raw_others_list_of_msc_technical_electives.md
# Copied: raw_bsc_practicalmachinelearningdeeplearning.md
# Copied: raw_raw_raw_bsc_networkandcybersecurity.s22.md
# Copied: raw_raw_raw_elective_ethicsandit.tex.md
# Copied: raw_raw_raw_msc_datasecurity.md
# Copied: raw_raw_raw_msc_behavioralandcognitiverobotics.md
# Copied: raw_raw_raw_elective_formalsoftwaredevelopmentofandroidapps.tex.md
# Copied: raw_bsc__game_theory.md
# Copied: raw_msc_advanced_statistics.md
# Copied: raw_raw_raw_bsc_.md
# Copied: raw_msc__venture_capital_and_growth_hacking.md
# Copied: raw_bsc__analytic_geometry_and_linear_algebra_i.f23.md
# Copied: raw_raw_raw_bsc_roboticsystems.md
# Copied: raw_bsc__reinforcement_learning.md
# Copied: raw_others_olegkiselev.md
# Copied: raw_others_faqstudents.md
# Copied: raw_raw_raw_bsc_operatingsystems%d1%8e.f21.md
# Copied: raw_bshe_introductiontoitentrepreneurship.md
# Copied: raw_others_evgeniizouev.md
# Copied: raw_bsc__analytic_geometry_and_linear_algebra_i.f22.md
# Copied: raw_bshe__human_and_animal_brain_representation_in_neurosciences.md
# Copied: raw_bsc__theoretical_computer_science.md
# Copied: raw_raw_raw_msc_advanced_machine_learning.md
# Copied: raw_bsc_sensorsandsensing.md
# Copied: raw_raw_raw_bsc_physicsi.f21.md
# Copied: raw_others_josephbrown.md
# Copied: raw_raw_raw_bsc__physical_culture_and_sport_nutrition.md
# Copied: raw_raw_raw_others_studentinformationpage.md
# Copied: raw_raw_raw_bsc_distributedandnetworkprogramming.f21.md
# Copied: raw_bsc_softwaresystemsdesign.md
# Copied: raw_raw_raw_mshe__it_product_development.md
# Copied: raw_raw_raw_msc_offensivetechnologies.md
# Copied: raw_raw_raw_elective_digitalsignalprocessing.tex.md
# Copied: raw_others_adilkhan.md
# Copied: raw_msc_analysis_software_artifacts.md
# Copied: raw_elective_industrialsoftwaretesting.tex.md
# Copied: raw_raw_raw_handbook_1. Academic Plan.md
# Copied: raw_raw_raw_msc__msc:_secure_development.md
# Copied: raw_msc__models_software_systems.md
# Copied: raw_raw_raw_others_paolociancarini.md
# Copied: raw_raw_raw_bsc__physics_ii.md
# Copied: raw_raw_raw_bsc_syllabi_table.md
# Copied: raw_bsc_advanceddatabases.md
# Copied: raw_bste__cross-platform_mobile_development_with_flutter.md
# Copied: raw_raw_raw_msc_computer_vision.md
# Copied: raw_elective_fundamentalsofinformationsecurity.tex.md
# Copied: raw_raw_raw_bsc_practicalmachinelearningdeeplearning.f21.md
# Copied: raw_msc_high-dimensional_data_analysis.md
# Copied: raw_raw_raw_bsc__data_mining.md
# Copied: raw_raw_raw_msc_modelssoftwaresystems.s22.md
# Copied: raw_raw_raw_bsc__it_product_development.md
# Copied: raw_bsc_mathematicalanalysisii.s23.md
# Copied: raw_raw_raw_others_summer_school.md
# Copied: raw_raw_raw_msc_computervision.s22.md
# Copied: raw_elective_humancomputerinteractiondesign.tex.md
# Copied: raw_raw_raw_all_schedule.md
# Copied: raw_others_academicleave.md
# Copied: raw_raw_raw_bsc__lean_software_development.md
# Copied: raw_msc_technicalelectives.md
# Copied: raw_raw_raw_clubs_Special interest clubs.md
# Copied: raw_raw_raw_bsc__history.md
# Copied: raw_others_how_to_moodle.md
# Copied: raw_bste_proceduralcontentgenerationforgames.md
# Copied: raw_raw_raw_bsc__mathematical_analysis_ii.md
# Copied: raw_raw_raw_others_educational_opportunities_for_alumni.md
# Copied: raw_raw_raw_bsc_introductiontobigdata.f21.md
# Copied: raw_bsc_advancedcompilersconstructionandprogramanalysis.md
# Copied: raw_raw_raw_elective_naturallanguageprocessingandmachinelearning.tex.md
# Copied: raw_others_yaroslavkholodov.md
# Copied: raw_raw_raw_msc_offensive_technologies.md
# Copied: raw_msc_computationalintelligence.s22.md
# Copied: raw_raw_raw_msc_managinsoftwaredevelopment_block2.md
# Copied: raw_raw_raw_bsc__information_retrieval.md
# Copied: raw_raw_raw_mste__ceo_toolkit.md
# Copied: raw_others_employmentsupports.md
# Copied: raw_raw_raw_bsc__total_virtualization.md
# Copied: raw_raw_raw_bsc_systemandnetworkadministration.f21.md
# Copied: raw_raw_raw_bste_distributedsystemsandmiddleware.md
# Copied: raw_raw_raw_elective_industrialprogramminginjava.tex.md
# Copied: raw_raw_raw_msc__secure_development.md
# Copied: raw_bsc__history.md
# Copied: raw_others_list_of_bsc_humanitarian_electives.md
# Copied: raw_msc_metricsandempiricalmethods.md
# Copied: raw_bsc__mathematical_analysis_i.f21.test.md
# Copied: raw_msc_computer_vision.md
# Copied: raw_raw_raw_bsc_microcontrollersandembeddedhardware.md
# Copied: raw_others_ms1and2.md
# Copied: raw_raw_raw_bsc__philosophy_ii.md
# Copied: raw_faq_Admin.md
# Copied: raw_elective_internationalbusinesslegalessentials.tex.md
# Copied: raw_msc_informationtheory.md
# Copied: raw_msc_architectures_software_systems.md
# Copied: raw_innopolis-university_apply.innopolis.university_faq.txt
# Copied: raw_raw_raw_others_manuelmazzara.md
# Copied: raw_raw_raw_msc_advancedmachinelearning.s22.md
# Copied: raw_raw_raw_bsc_softwareproject.md
# Copied: raw_raw_raw_bsc_introductiontocomputervision.md
# Copied: raw_msc__empirical_methods.md
# Copied: raw_raw_raw_others_list_of_bsc_humanitarian_electives.md
# Copied: raw_others_winter_school.md
# Copied: raw_msc__advanced_information_retrieval.md
# Copied: raw_bsc_englishforacademicpurposesi.f21.md
# Copied: raw_raw_raw_bsc__programming_paradigms.md
# Copied: raw_raw_raw_bsc_project.md
# Copied: raw_others_kirillpoletkin.md
# Copied: raw_raw_raw_bsc_practicalmachinelearningdeeplearning.md
# Copied: raw_elective_patternorienteddesign.tex.md
# Copied: raw_msc_advancednetworking.md
# Copied: raw_raw_raw_msc_requirements_engineering.md
# Copied: raw_mste__it_course.md
# Copied: raw_mste__leadership_in_entrepreneurship.md
# Copied: raw_others_employment_supports_and_educational_opportunities_for_alumni.md
# Copied: raw_raw_raw_bsc_introductiontoprogramming.md
# Copied: raw_raw_raw_bsc__human-ai_interaction_design.md
# Copied: raw_bste_distributedsystemsandmiddleware.md
# Copied: raw_msc__fundamentals_of_robot_control.md
# Copied: raw_bsc_microcontrollersandembeddedhardware.md
# Copied: raw_raw_raw_msc_analysis_software_artifacts.md
# Copied: raw_bsc_nonlinearoptimization.md
# Copied: raw_raw_raw_bsc__system_and_network_administration.md
# Copied: raw_bsc_advancedcompilerconstructionandprogramanalysis.md
# Copied: raw_bsc__compilers_construction.md
# Copied: raw_bsc_discretemathandlogic.md
# Copied: raw_raw_raw_bsc__physical_culture_and_sport_psychology.md
# Copied: raw_elective_entrepreneurship.tex.md
# Copied: raw_raw_raw_bsc_logic_and_discrete_mathematics.md
# Copied: raw_raw_raw_bste__computer_graphics_in_game_development.md
# Copied: raw_raw_raw_bsc_computerarchitecture.md
# Copied: raw_raw_raw_others_list_of_msc_humanitarian_electives.md
# Copied: raw_raw_raw_bsc__software_systems_design.md
# Copied: raw_raw_raw_others_scientific_sources_and_material.md
# Copied: raw_raw_raw_innopolis-university_apply.innopolis.university_master.txt
# Copied: raw_raw_raw_bsc_softwareverificationtesting.md
# Copied: raw_raw_raw_bsc_mathematicalanalysisii.md
# Copied: raw_raw_raw_bsc_controltheory.md
# Copied: raw_bsc_physicalcultureandsport.md
# Copied: raw_raw_raw_bsc__analytic_geometry_and_linear_algebra_ii.s22.md
# Copied: raw_bsc_systemandnetworkadministration.md
# Copied: raw_msc_securitysystemsnetworks.md
# Copied: raw_others_ahsankazmi.md
# Copied: raw_raw_raw_others_maratmingazov.md
# Copied: raw_raw_raw_elective_fundamentalsrobotcontrol.tex.md
# Copied: raw_raw_raw_bsc__theoretical_computer_science.md
# Copied: raw_raw_raw_others_olegkiselev.md
# Copied: raw_bsc_academicresearchandwritingculture2.s22.md
# Copied: raw_raw_raw_clubs_Sport clubs.md
# Copied: raw_msc_advancedinformationretrieval.s22.md
# Copied: raw_bste_itproductdevelopment.md
# Copied: raw_raw_raw_bsc__differential_equations.f23.md
# Copied: raw_raw_raw_handbook_11. Volunteering & Innopoints.md
# Copied: raw_clubs_Tech clubs.md
# Copied: raw_others_giancarlosucci.md
# Copied: raw_msc_communication.s22.md
# Copied: raw_raw_raw_bsc_analyticgeometryandlinearalgebrai.f21.md
# Copied: raw_bste_introductiontofunctionalprogrammingandscalalanguage.md
# Copied: raw_raw_raw_bsc__probability_and_statistics.f22.md
# Copied: raw_all_studyplan.md
# Copied: raw_raw_raw_others_electives.md
# Copied: raw_raw_raw_msc_architecturessoftwaresystems.md
# Copied: raw_raw_raw_others_kirillpoletkin.md
# Copied: raw_msc__cybercrime_forensics.md
# Copied: raw_msc_machinelearning.f21.md
# Copied: raw_others_andreysadovykh.md
# Copied: raw_raw_raw_others_nursultan_askarbekuly.md
# Copied: raw_bsc__introduction_to_artificial_intelligence.md
# Copied: raw_raw_raw_bsc__nature_inspired_computing.md
# Copied: raw_raw_raw_bsc_introductiontomachinelearning.f21.md
# Copied: raw_raw_raw_bsc_introductiontoprogramming.f21.md
# Copied: raw_raw_raw_bsc_physicalcultureandsport.md
# Copied: raw_raw_raw_bsc_logicincomputerscience.md
# Copied: raw_raw_raw_faq_Admin.md
# Copied: raw_raw_raw_others_olegbulichev.md
# Copied: raw_others_professorinformationpage.md
# Copied: raw_raw_raw_bsc_introductiontoprogrammingi.md
# Copied: raw_msc_highdimensionaldataanalysis.md
# Copied: raw_bsc_mathematicalanalysisii.s22.md
# Copied: raw_msc__analysis_software_artifacts.md
# Copied: raw_raw_raw_bsc_advancedcompilerconstructionandprogramanalysis.md
# Copied: raw_msc__architectures_of_software_systems.md
# Copied: raw_msc_machinelearning.md
# Copied: raw_raw_raw_mhe_itproductdevelopment.md
# Copied: raw_raw_raw_others_faqforofferingelective.md
# Copied: raw_bsc__it_product_development.md
# Copied: raw_msc_bigdatatechnologiesandanalytics.md
# Copied: raw_raw_raw_bsc__compilers_construction.md
# Copied: raw_bsc_distributedandnetworkprogramming.md
# Copied: raw_raw_raw_bsc__introduction_to_artificial_intelligence.md
# Copied: raw_bsc_softwarearchitectures.md
# Copied: raw_bsc__mechanics_and_machines.md
# Copied: raw_raw_raw_bsc_physicsi.md
# Copied: raw_bsc_advanced_algorithms.md
# Copied: raw_raw_raw_bsc_humancomputerinterfaces.md
# Copied: raw_msc__unit_economics_in_it_business.md
# Copied: raw_raw_raw_others_newcomer%27s.md
# Copied: raw_others_artemburmyakov.md
# Copied: raw_raw_raw_bsc__mathematical_analysis_i.md
# Copied: raw_raw_raw_bsc__theoretical_mechanics.md
# Copied: raw_raw_raw_clubs_Art clubs.md
# Copied: raw_raw_raw_bsc_naturallanguageprocessing.md
# Copied: raw_raw_raw_msc_highdimensionaldataanalysis.md
# Copied: raw_raw_raw_msc__security_of_systems_and_networks.md
# Copied: raw_others_whatififailed.md
# Copied: raw_bsc_analyticgeometryandlinearalgebraii.s22.md
# Copied: raw_msc__computational_intelligence.md
# Copied: raw_innopolis-university_apply.innopolis.university_master.txt
# Copied: raw_raw_raw_faq_Extracurricular.md
# Copied: raw_elective_leanstartupmethodology.tex.md
# Copied: raw_raw_raw_msc__high-dimensional_data_analysis.md
# Copied: raw_elective_bitcoinandcryptocurrencytechnologies.tex.md
# Copied: raw_raw_raw_others_adilkhan.md
# Copied: raw_raw_raw_bsc__mechatronics.md
# Copied: raw_bsc_differentialequations.f21.md
# Copied: raw_elective_introductiontocareerdevelopment.tex.md
# Copied: raw_raw_raw_msc__empirical_methods.md
# Copied: raw_raw_raw_bsc_introductiontocomputervision.f21.md
# Copied: raw_raw_raw_msc__ceo_toolkit_strategy,_operations,_finance,_hr,_legal_aspects,_ip_law_and_innovations.md
# Copied: raw_raw_raw_bshe_designfiction.md
# Copied: raw_raw_raw_others_scientificsourcesandmaterial.md
# Copied: raw_msc_dynamicsofnonlinearroboticsystems.md
# Copied: raw_innopolis-university_apply.innopolis.ru_get-in.txt
# Copied: raw_bsc_securesystemdevelopment.md
# Copied: raw_others_stanislavprotasov.md
# Copied: raw_msc_empirical_methods.md
# Copied: raw_bsc_softwarequalityandreliability.s21.md
# Copied: raw_bsc__analytic_geometry_and_linear_algebra_ii.s22.md
# Copied: raw_others_alexandertormasov.md
# Copied: raw_bsc__data_mining.md
# Copied: raw_bsc__physical_culture_and_sport_nutrition.md
# Copied: raw_raw_raw_bsc__advanced_compilers_construction_and_program_analysis.md
# Copied: raw_msc_highdimensionaldataanalysis.s22.md
# Copied: raw_bsc_controltheory.md
# Copied: raw_raw_raw_msc_advancedmachinelearning.md
# Copied: raw_bsc_project.md
# Copied: raw_raw_raw_others_whatififailed.md
# Copied: raw_bste__art_of_reading_learning_and_understanding.md
# Copied: raw_raw_raw_bsc_mechatronics.f21.md
# Copied: raw_raw_raw_bsc_humanitieselectives.md
# Copied: raw_raw_raw_msc_advancedrobotics.s22.md
# Copied: raw_bshe_introductiontocareerdevelopment.md
# Copied: raw_raw_raw_msc_technicalelectives.md
# Copied: raw_others_saifmohammedsabri.md
# Copied: raw_raw_raw_bsc__academic_research_and_writing_culture.md
# Copied: raw_raw_raw_others_exchange_program.md
# Copied: raw_bsc_devopsengineering.md
# Copied: raw_bshe__leadership_in_entrepreneurship.md
# Copied: raw_others_faqforofferingelective.md
# Copied: raw_raw_raw_msc_optimization.md
# Copied: raw_bsc_physicalcultureandsport.s22.md
# Copied: raw_bsc_fundamentals_of_computer_security.md
# Copied: raw_raw_raw_elective_internationalbusinesslegalessentials.tex.md
# Copied: raw_raw_raw_mste__market_research_for_it_startups.md
# Copied: raw_bshe_scienceethics.md
# Copied: raw_msc_modelssoftwaresystems.s22.md
# Copied: raw_bsc_fundamentalsofsoftwareengineering.md
# Copied: raw_raw_raw_bsc_sensorsandsensing.md
# Copied: raw_raw_raw_msc_syllabi_table.md
# Copied: raw_raw_raw_msc_advancednetworking.md
# Copied: raw_raw_raw_bshe__fundraising,_go_to_market_and_hyper_growth_for_startups.md
# Copied: raw_others_mohammedrezabahrami.md
# Copied: raw_msc__unit-economics_for_it_startups.md
# Copied: raw_raw_raw_msc_high-dimensional_data_analysis.md
# Copied: raw_raw_raw_others_exchange_program_%26_summer_school.md
# Copied: raw_raw_raw_msc__it_product_development.md
# Copied: raw_raw_raw_bsc__data_structures_algorithms.md
# Copied: raw_msc__managing_software_development.md
# Copied: raw_bsc__software_project.md
# Copied: raw_raw_raw_elective_bitcoinandcryptocurrencytechnologies.tex.md
# Copied: raw_raw_raw_elective_internationaltradeproceduresandregulations.tex.md
# Copied: raw_elective_moderncppnewlanguageconceptsfeaturesandmechanisms.tex.md
# Copied: raw_raw_raw_msc_datamining.md
# Copied: raw_msc__big_data_technologies_and_analytics.md
# Copied: raw_elective_ethicsandit.tex.md
# Copied: raw_bsc_introductiontoprogramming.f21.md
# Copied: raw_bsc_syllabi_index.md
# Copied: raw_raw_raw_others_exchange.md
# Copied: raw_bsc_history.md
# Copied: raw_bsc_academicresearchandwritingculture2.md
# Copied: raw_others_overallregulations.md
# Copied: raw_raw_raw_msc__unit-economics_for_it_startups.md
# Copied: raw_msc_securityofsystemsandnetworks.md
# Copied: raw_raw_raw_bsc__software_project.md
# Copied: raw_bshe_venture_capital_hacks_in_it_industry:_from_zero_to_negotiating_and_investment_deal.md
# Copied: raw_raw_raw_bsc__mathematical_analysis_i.f21.md
# Copied: raw_bsc_signalsandsystems.s22.md
# Copied: raw_msc_modelssoftwaresystems.md
# Copied: raw_bsc_mechanicsandmachines.md
# Copied: raw_raw_raw_msc_datamodelinganddatabases2.md
# Copied: raw_raw_raw_bsc_philosophyii.md
# Copied: raw_others_artemkruglov.md
# Copied: raw_raw_raw_msc_bigdatatechnologiesandanalytics.md
# Copied: raw_raw_raw_others_newsboard.md
# Copied: raw_msc_sensingperceptionactuation.md
# Copied: raw_raw_raw_bsc_statisticaltechniquesfordatascience.s22.md
# Copied: raw_others_studentinformationpage.md
# Copied: raw_msc_gametheory.md
# Copied: raw_raw_raw_bsc_datamining.s22.md
# Copied: raw_msc_advanced_information_retrieval.md
# Copied: raw_bsc_syllabi_table.md
# Copied: raw_raw_raw_msc_communication.md
# Copied: raw_msc_computervision.md
# Copied: raw_bsc__capstone_project.md
# Copied: raw_handbook_11. Volunteering & Innopoints.md
# Copied: raw_raw_raw_msc__sensing_perception_actuation.md
# Copied: raw_others_electives.md
# Copied: raw_msc_unit-economicsforitstartups.md
# Copied: raw_raw_raw_elective_softwareprojectmanagement.tex.md
# Copied: raw_raw_raw_phd_syllabi_table.md
# Copied: raw_raw_raw_msc_analyticalgeometryandlinearalgebrai.md
# Copied: raw_raw_raw_msc_managingsoftwaredevelopment.f21.md
# Copied: raw_raw_raw_others_list_of_msc_technical_electives.md
# Copied: raw_others_semenkurkin.md
# Copied: raw_elective_introductiontoconvexoptimization.tex.md
# Copied: raw_msc_advanced_robotics.md
# Copied: raw_raw_raw_bsc__software_quality,_reliability_and_security.md
# Copied: raw_raw_raw_bste_marketresearchforitstartups.md
# Copied: raw_bshe__fundraising,_go_to_market_and_hyper_growth_for_startups.md
# Copied: raw_raw_raw_bsc_devopsengineering.f21.md
# Copied: raw_msc__marketing_and_sales_for_it_business.md
# Copied: raw_raw_raw_others_employmentsupports.md
# Copied: raw_bsc_differentialequations.md
# Copied: raw_others_faq_for_offering_an_elective.md
# Copied: raw_bsc_mechatronics.md
# Copied: raw_raw_raw_others_anastasiyapuzankova.md
# Copied: raw_raw_raw_msc_classicalinternetapplications.md
# Copied: raw_raw_raw_elective_venturecapitalhacksfromzerotonegotiatinganinvestmentdeal.tex.md
# Copied: raw_raw_raw_bsc_mathematicalanalysisi.f21.md
# Copied: raw_raw_raw_bsc__analytic_geometry_and_linear_algebra_i.f22.md
# Copied: raw_raw_raw_msc__machine_learning.md
# Copied: raw_msc_empiricalmethods.md
# Copied: raw_others_summer_school.md
# Copied: raw_msc_optimization.f21.md
# Copied: raw_others_thesisguidelines.md
# Copied: raw_msc_humanitarianelectives.md
# Copied: raw_bsc_englishforacademicpurposesii.md
# Copied: raw_msc_advancedrobotics.s22.md
# Copied: raw_raw_raw_elective_decentralizedapplicationsonethereumplatform.tex.md
# Copied: raw_msc_machine_learning.md
# Copied: raw_elective_introductiontocommunication.tex.md
# Copied: raw_raw_raw_elective_economicsofentrepreneurship.tex.md
# Copied: raw_raw_raw_elective_introductiontocommunication.tex.md
# Copied: raw_msc_advancedsecurity.md
# Copied: raw_raw_raw_msc_advanced_statistics.md
# Copied: raw_msc_requirementsengineering.f21.md
# Copied: raw_msc_internetworkingandrouting.md
# Copied: raw_raw_raw_msc_dynamicsofnonlinearroboticsystems.md
# Copied: raw_raw_raw_others_ivankonyukhov.md
# Copied: raw_bsc_devopsengineering.f21.md
# Copied: raw_raw_raw_bsc_introductiontoprogrammingii.md
# Copied: raw_raw_raw_elective_negotiatingprocessesforthepromotionofcooperationandhumanrightsininternationalregimeshistory.tex.md
# Copied: raw_others_scientific_sources_and_material.md
# Copied: raw_bsc__introduction_to_big_data.md
# Copied: raw_raw_raw_msc__architectures_of_software_systems.md
# Copied: raw_bsc_datastructuresalgorithmsii.md
# Copied: raw_raw_raw_bsc_history.f21.md
# Copied: raw_msc_dynamics_of_non_linear_robotic_systems.md
# Copied: raw_raw_raw_bsc_advancedcompilersconstructionandprogramanalysis.md
# Copied: raw_raw_raw_bsc_businessanalytics.md
# Copied: raw_bsc__nature_inspired_computing.md
# Copied: raw_msc_sensing_perception_actuation.md
# Copied: raw_raw_raw_msc_oopandsoftwarearchitechture.md
# Copied: raw_others_manuelmazzara.md
# Copied: raw_bsc_phil2-knowledgeandperception.md
# Copied: raw_bsc__probability_and_statistics.s22.md
# Copied: raw_handbook_9.5. Exchange Opportunities.md
# Copied: raw_raw_raw_msc_largesystems.s22.md
# Copied: raw_raw_raw_bsc_nonlinearoptimization.md
# Copied: raw_msc_computational_intelligence.md
# Copied: raw_raw_raw_bsc_distributedandnetworkprogramming.md
# Copied: raw_raw_raw_bshe__introduction_to_it_entrepreneurship.md
# Copied: raw_raw_raw_bste_reinforcmentlearning.md
# Copied: raw_raw_raw_bsc_mathematicalanalysisi.md
# Copied: raw_raw_raw_handbook_9.5. Exchange Opportunities.md
# Copied: raw_raw_raw_bsc_probabilityandstatistics.md
# Copied: raw_raw_raw_msc_sensing_perception_actuation.md
# Copied: raw_raw_raw_bsc_programmingparadigms.f21.md
# Copied: raw_raw_raw_bsc_informationretrieval.s22.md
# Copied: raw_raw_raw_others_munirmakhmutov.md
# Copied: raw_raw_raw_others_about_lecturing_a_course.md
# Copied: raw_others_munirmakhmutov.md
# Copied: raw_raw_raw_others_list_of_bsc_technical_electives.md
# Copied: raw_bste_reinforcmentlearning.md
# Copied: raw_raw_raw_bsc__introduction_to_artificial_intelligence.s22.md
# Copied: raw_bsc_syllabi_table_3%2b1.md
# Copied: raw_raw_raw_bsc_introductiontoprogrammingii.s22.md
# Copied: raw_bsc__distributed_and_network_programming.md
# Copied: raw_bsc__lean_software_development.md
# Copied: raw_msc_architectures_of_software_systems.md
# Copied: raw_msc_offensive_technologies.md
# Copied: raw_bsc__analytic_geometry_and_linear_algebra_ii.s23.md
# Copied: raw_bsc_softwarequalityandreliability.md
# Copied: raw_raw_raw_bsc_datamodelingdatabasesii.md
# Copied: raw_msc_managing_software_development.md
# Copied: raw_raw_raw_msc__advanced_statistics.md
# Copied: raw_raw_raw_bsc_advanceddatabases.md
# Copied: raw_raw_raw_bsc_introductiontobigdata.md
# Copied: raw_bsc_history.f21.md
# Copied: raw_raw_raw_others_newsboard,_channels_and_groups_links.md
# Copied: raw_raw_raw_bshe_techstartudesign.md
# Copied: raw_raw_raw_msc_advanced_information_retrieval.md
# Copied: raw_bsc__human-ai_interaction_design.md
# Copied: raw_others_list_of_all_courses.md
# Copied: raw_bste_marketresearchforitstartups.md
# Copied: raw_raw_raw_bsc_introductiontoartificialintelligence.md
# Copied: raw_others_thesis_guidelines.md
# Copied: raw_raw_raw_others_artemkruglov.md
# Copied: raw_msc__secure_development.md
# Copied: raw_msc_offensivetechnologies.s22.md
# Copied: raw_others_professor_information_page.md
# Copied: raw_bsc_mobileapplicationdevelopment-1.md
# Copied: raw_raw_raw_bsc_mobileapplicationdevelopment.md
# Copied: raw_bsc_introductiontoartificialintelligence.md
# Copied: raw_raw_raw_bsc_differentialequations.f21.md
# Copied: raw_bste_servicedesign.md
# Copied: raw_bsc__introduction_to_programming.md
# Copied: raw_bsc_businessanalytics.md
# Copied: raw_elective_negotiatingprocessesforthepromotionofcooperationandhumanrightsininternationalregimeshistory.tex.md
# Copied: raw_bsc_computerarchitecture.md
# ...
# Copied: introductiontocareerdevelopment.md
# Copied: venture_capital_hacks_in_it_industry:_from_zero_to_negotiating_and_investment_deal.md
# Copied: introductiontoeconomicsofentrepreneurship.md
# Copied: venturecapitalhacksinitindustry.md
# Copied: _it_product_development.md
# Copied: empiricalmethods.md
# Copied: syllabi_index.md
# Copied: high-dimensional_data_analysis.md
# Copied: dynamicsofnonlinearroboticsystems.f21.md
# Copied: _advanced_information_retrieval.md
# Copied: controltheorylinearcontrol.md
# Copied: _venture_capital_and_growth_hacking.md
# Copied: _advanced_statistics.md
# Copied: advanced_robotics.md
# Copied: offensivetechnologies.s22.md
# Copied: models_software_systems.md
# Copied: classicalinternetapplications.f21.md
# Copied: _optimization.md
# Copied: _advanced_security.md
# Copied: _machine_learning.md
# Copied: computationalintelligence.s22.md
# Copied: _requirements_engineering.md
# Copied: datamining.md
# Copied: inter_networking_and_routing.md
# Copied: securitysystemsnetworks.md
# Copied: managingsoftwaredevelopment.f21.md
# Copied: randomizedalgorithms.md
# Copied: advanced_security.md
# Copied: datamodelinganddatabases2.md
# Copied: highdimensionaldataanalysis.s22.md
# Copied: _inter_networking_and_routing.md
# Copied: _security_of_systems_and_networks.md
# Copied: managingsoftwaredevelopment%d1%8e.f21.md
# Copied: _founder_project.md
# Copied: internetworkingandrouting.md
# Copied: computer_vision.md
# Copied: modelssoftwaresystems.s22.md
# Copied: _large_systems.md
# Copied: classical_internet_applications.md
# Copied: _personal_software_process.md
# Copied: _secure_development.md
# Copied: dynamicsofnonlinearroboticsystems.md
# Copied: _syllabi_index.md
# Copied: advancedstatistics.s22.md
# Copied: requirements_engineering.md
# Copied: computational_intelligence.md
# Copied: advancedinformationretrieval.md
# Copied: architectures_software_systems.md
# Copied: _computer_vision.md
# Copied: advancednetworking.f21.md
# Copied: advancedrobotics.s22.md
# Copied: metricsandempiricalmethods.md
# Copied: unit-economicsforitstartups.md
# Copied: _communication.md
# Copied: analysis_software_artifacts.md
# Copied: oopandsoftwarearchitechture.md
# Copied: optimization.md
# Copied: communication.s22.md
# Copied: humanitarianelectives.md
# Copied: bigdatatechnologiesandanalytics.md
# Copied: _models_software_systems.md
# Copied: machinelearning.f21.md
# Copied: personalsoftwareprocess.md
# Copied: _analysis_software_artifacts.md
# Copied: _architectures_of_software_systems.md
# Copied: architecturessoftwaresystems.md
# Copied: largesystems.s22.md
# Copied: advancedsecurity.md
# Copied: bigdatatechnologiesandanalytics.f21.md
# Copied: gametheory.md
# Copied: cybercrime_forensics.md
# Copied: analysissoftwareartifacts.md
# Copied: advancedinformationretrieval.s22.md
# Copied: big_data_technologies_and_analytics.md
# Copied: syllabi_table.md
# Copied: architecturessoftwaresystems.s22.md
# Copied: _empirical_methods.md
# Copied: sensingperceptionactuation.f21.md
# Copied: analysissoftwareartifacts.s22.md
# Copied: communication.md
# Copied: advancedstatistics.md
# Copied: _managing_software_development.md
# Copied: advanced_statistics.md
# Copied: _fundamentals_of_robot_control.md
# Copied: classicalinternetapplications.md
# Copied: _advanced_machine_learning.md
# Copied: advanced_networking.md
# Copied: internetworkingandrouting.f21.md
# Copied: sensing_perception_actuation.md
# Copied: _it_product_development.md
# Copied: advancedmachinelearning.s22.md
# Copied: sensingperceptionactuation.md
# Copied: largeinstallationadministration.md
# Copied: computervision.md
# Copied: technicalelectives.md
# Copied: _advanced_robotics.md
# Copied: informationtheory.md
# Copied: _venture_and_growth_hacking.md
# Copied: advancednetworking.md
# Copied: _ceo_toolkit_strategy,_operations,_finance,_hr,_legal_aspects,_ip_law_and_innovations.md
# Copied: computationalintelligence.md
# Copied: advancedrobotics.md
# Copied: datasecurity.md
# Copied: empirical_methods.md
# Copied: _it_business_start.md
# Copied: advanced_information_retrieval.md
# Copied: advancedsecurity.s22.md
# Copied: _msc:_secure_development.md
# Copied: _sensing_perception_actuation.md
# Copied: managinsoftwaredevelopment_block1.md
# Copied: requirementsengineering.md
# Copied: _unit_economics_in_it_business.md
# Copied: empiricalmethods.f21.md
# Copied: architectures_of_software_systems.md
# Copied: distributedsystems.md
# Copied: personal_software_process.md
# Copied: offensivetechnologies.md
# Copied: probabilitystatistics.md
# Copied: large_systems.md
# Copied: managing_software_development.md
# Copied: _leadership_in_entrepreneurship.md
# Copied: offensive_technologies.md
# Copied: dynamics_of_non_linear_robotic_systems.md
# Copied: securityofsystemsandnetworks.md
# Copied: machine_learning.md
# Copied: fundamentalsofrobotcontrol.md
# Copied: advanced_machine_learning.md
# Copied: _offensive_technologies.md
# Copied: highdimensionaldataanalysis.md
# Copied: modelssoftwaresystems.md
# Copied: _cybercrime_forensics.md
# Copied: machinelearning.md
# Copied: computervision.s22.md
# Copied: unit-economics_for_it_startups.md
# Copied: cybercrimeforensics.md
# Copied: _dynamics_of_non_linear_robotic_systems.md
# Copied: _advanced_networking.md
# Copied: managinsoftwaredevelopment_block2.md
# Copied: researchmethods.md
# Copied: _marketing_and_sales_for_it_business.md
# Copied: cybercrimeforensics.s22.md
# Copied: _unit-economics_for_it_startups.md
# Copied: _high-dimensional_data_analysis.md
# Copied: requirementsengineering.f21.md
# Copied: _computational_intelligence.md
# Copied: managingsoftwaredevelopment.md
# Copied: _classical_internet_applications.md
# Copied: analyticalgeometryandlinearalgebrai.md
# Copied: behavioralandcognitiverobotics.md
# Copied: advancedmachinelearning.md
# Copied: personalsoftwareprocess.f21.md
# Copied: _big_data_technologies_and_analytics.md
# Copied: optimization.f21.md
# Copied: neuroscience.md
# Copied: _security_and_interpretability_of_machine_learning.md
# Copied: highperformancecomputing.md
# Copied: reinforcmentlearning.md
# Copied: _cross-platform_mobile_development_with_flutter.md
# Copied: introductiontofunctionalprogrammingandscalalanguage.md
# Copied: marketresearchforitstartups.md
# Copied: _art_of_reading_learning_and_understanding.md
# Copied: itproductdevelopment.md
# Copied: servicedesign.md
# Copied: _applied_machine_learning.md
# Copied: frontendwebdevelopment.md
# Copied: advancedtopicsinsoftwaretesting.md
# Copied: _distributed_systems.md
# Copied: _the_security_and_interpretability_of_machine_learning.md
# Copied: proceduralcontentgenerationforgames.md
# Copied: _advanced_linux.md
# Copied: introductiontopracticalartificialintelligence.md
# Copied: introductiontoquantumprogramming.md
# Copied: advancedcpp.md
# Copied: _computer_graphics_in_game_development.md
# Copied: distributedsystemsandmiddleware.md
# Copied: discretemathandlogic.md
# Copied: advanced_algorithms.md
# Copied: softwarearchitectures.md
# Copied: _probability_and_statistics.f23.md
# Copied: syllabi_index.md
# Copied: _academic_research_and_writing_culture_ii.md
# Copied: statisticaltechniquesfordatascience.s21.md
# Copied: practicalmachinelearningdeeplearning.md
# Copied: fundamentalsofcomputersecurity.md
# Copied: humanitieselectives.md
# Copied: academicresearchandwritingculture.md
# Copied: _capstone_project.md
# Copied: _differential_equations.f22.md
# Copied: _total_virtualization.md
# Copied: digitalsignalprocessing.md
# Copied: _software_quality,_reliability_and_security.md
# Copied: introductiontoprogramming.md
# Copied: datastructuresalgorithmsii.md
# Copied: softwarearchitectures.old.md
# Copied: _statistical_techniques_for_data_science.md
# Copied: networks.md
# Copied: networks.s22.md
# Copied: logic_and_discrete_mathematics.f21.md
# Copied: _game_theory.md
# Copied: naturallanguageprocessing.md
# Copied: _dev_ops_engineering.md
# Copied: _advanced_compilers_construction_and_program_analysis.md
# Copied: academicresearchandwritingculture2.s22.md
# Copied: distributedledgerstechnologies.md
# Copied: introductiontoprogramming.f21.md
# Copied: _compilers_construction.md
# Copied: softwaresystemsdesign.f21.md
# Copied: theoreticalcomputerscience.s22.md
# Copied: distributedandnetworkprogramming.f21.md
# Copied: _introduction_to_robotics.md
# Copied: _mechatronics.md
# Copied: _networks.md
# Copied: physicalcultureandsport.md
# Copied: _history.md
# Copied: _reinforcement_learning.md
# Copied: systemtheory.md
# Copied: sensorsandsensing.md
# Copied: datamining.md
# Copied: _analytic_geometry_and_linear_algebra_i.f22.md
# Copied: fundamentalsofgraphicsandvirtualrealities.md
# Copied: informationretrieval.md
# Copied: mathematicalanalysisi.f21.md
# Copied: devopsengineering.md
# Copied: _introduction_to_artificial_intelligence.md
# Copied: mathematicalmodeling.md
# Copied: _software_project.md
# Copied: nonlinearcontroltheory.md
# Copied: computerarchitecture.f21.md
# Copied: _physical_culture_and_sport_psychology.md
# Copied: systemandnetworkadministration.f21.md
# Copied: computerarchitecture.md
# Copied: roboticsystems.md
# Copied: _probability_and_statistics.f22.md
# Copied: _secure_system_development.md
# Copied: softwareverificationtesting.md
# Copied: compilersconstruction.s22.md
# Copied: analyticgeometryandlinearalgebrai.f21.md
# Copied: _introduction_to_programming_ii.md
# Copied: statisticaltechniquesfordatascience..md
# Copied: _human-ai_interaction_design.md
# Copied: _introduction_to_computer_vision.md
# Copied: embeddedandsharedmemoryprogramming.md
# Copied: _lean_software_development.md
# Copied: mathematicalanalysisii.f21.md
# Copied: history.f21.md
# Copied: datamining.s22.md
# Copied: phil1-introductiontologic.md
# Copied: introductiontoprogrammingi.old.md
# Copied: introductiontoprogrammingi.md
# Copied: logic_and_discrete_mathematics.md
# Copied: advanceddatabases.s22.md
# Copied: analyticgeometryandlinearalgebrai.md
# Copied: distributedsytemsandcloudcomputing.md
# Copied: _data_structures_algorithms.md
# Copied: numericalmodelling.md
# Copied: softwarequalityandreliability.md
# Copied: _distributed_and_network_programming.md
# Copied: _mathematical_analysis_ii.md
# Copied: securesystemdevelopment.md
# Copied: leansoftwaredevelopment.s22.md
# Copied: analyticgeometryandlinearalgebraii.md
# Copied: naturallanguageprocessing.s22.md
# Copied: englishforacademicpurposesii.s22.md
# Copied: history.md
# Copied: informationretrieval.s22.md
# Copied: controltheory.s22.md
# Copied: roboticsystems.s22.md
# Copied: _analytic_geometry_and_linear_algebra_ii.s23.md
# Copied: mathematicalanalysisii.s22.md
# Copied: microcontrollersandembeddedhardware.md
# Copied: physicsi.f21.md
# Copied: networkandcybersecurity.md
# Copied: _nature_inspired_computing.md
# Copied: datamodelingdatabasesii.md
# Copied: _introduction_to_big_data.md
# Copied: programmingparadigms.f21.md
# Copied: businessanalytics.md
# Copied: _theoretical_mechanics.md
# Copied: introductiontoartificialintelligence.md
# Copied: _practical_machine_learning_deep_learning.md
# Copied: _introduction_to_machine_learning.md
# Copied: .md
# Copied: _system_and_network_administration.md
# Copied: networkandcybersecurity.s22.md
# Copied: gametheory.md
# Copied: syllabi_table.md
# Copied: compilersconstruction.md
# Copied: _theoretical_computer_science.md
# Copied: _analytic_geometry_and_linear_algebra_ii.md
# Copied: englishforacademicpurposesi.md
# Copied: statisticaltechniquesfordatascience.s22.md
# Copied: academicresearchandwritingculture2.md
# Copied: _software_architectures.md
# Copied: mechatronics.md
# Copied: devopsengineering.f21.md
# Copied: _probability_and_statistics.md
# Copied: mobileapplicationdevelopment.md
# Copied: physicsi.md
# Copied: fundamentals.md
# Copied: _mathematical_analysis_i.f21.test.md
# Copied: _computer_architecture.md
# Copied: introductiontomachinelearning.md
# Copied: physicsii.md
# Copied: natureinspiredcomputing.md
# Copied: softwareproject.md
# Copied: mobileapplicationdevelopment-1.md
# Copied: advancedcompilersconstructionandprogramanalysis.md
# Copied: _mathematical_analysis_ii.s23.md
# Copied: _academic_research_and_writing_culture.md
# Copied: fundamentals_of_computer_security.md
# Copied: _operating_systems.md
# Copied: _analytic_geometry_and_linear_algebra_i.f21.md
# Copied: _introduction_to_programming.md
# Copied: mechanicsandmachines.s22.md
# Copied: _signals_and_systems.md
# Copied: introductiontorobotics.md
# Copied: _mathematical_analysis_i.md
# Copied: _it_product_development.md
# Copied: _analytic_geometry_and_linear_algebra_i.f23.md
# Copied: mathematicalanalysisii.md
# Copied: nonlinearoptimization.md
# Copied: _analytic_geometry_and_linear_algebra_i.md
# Copied: _mathematical_analysis_i.f22.md
# Copied: _advanced_databases.md
# Copied: signalsandsystems.md
# Copied: philosophyii.md
# Copied: _analytic_geometry_and_linear_algebra_ii.s22.md
# Copied: informationtheory.md
# Copied: humancomputerinterfaces.md
# Copied: physicsii.s22.md
# Copied: _control_theory.md
# Copied: introductiontocomputervision.f21.md
# Copied: theoreticalmechanics.md
# Copied: probabilityandstatistics.md
# Copied: leansoftwaredevelopment.md
# Copied: introductiontobigdata.md
# Copied: introductiontobigdata.f21.md
# Copied: _data_mining.md
# Copied: softwarequalityandreliability.s21.md
# Copied: controltheory.md
# Copied: programmingparadigms.md
# Copied: technicalelective.md
# Copied: _logic_and_discrete_mathematics.md
# Copied: _mathematical_analysis_i.f21.md
# Copied: mathematicalanalysisi.md
# Copied: introductiontomachinelearning.f21.md
# Copied: gametheory.s22.md
# Copied: _differential_equations.f23.md
# Copied: analyticalgeometryandlinearalgebrai-cs.md
# Copied: mathematicalanalysisii.s23.md
# Copied: advancedcompilerconstructionandprogramanalysis.md
# Copied: _differential_equations.md
# Copied: _network_and_cyber_security.md
# Copied: softwaresystemsdesign.md
# Copied: _mechanics_and_machines.md
# Copied: practicalmachinelearningdeeplearning.f21.md
# Copied: operatingsystems.f21.md
# Copied: _programming_paradigms.md
# Copied: introductiontocomputervision.md
# Copied: logicincomputerscience.md
# Copied: _physics_ii.md
# Copied: _advanced_linux.md
# Copied: _information_retrieval.md
# Copied: advancedalgorithms.md
# Copied: _robotic_systems.md
# Copied: introductiontoprogrammingii.s22.md
# Copied: _physics_i.md
# Copied: datastructuresalgorithms.md
# Copied: _introduction_to_optimization.f22.md
# Copied: _philosophy_ii.md
# Copied: sensorsandsensing.s22.md
# Copied: cloudcomputing.md
# Copied: project.md
# Copied: phil2-knowledgeandperception.md
# Copied: differentialequations.md
# Copied: physicalcultureandsport.s22.md
# Copied: logic_and_discrete_mathematics.f22.md
# Copied: introductiontoprogrammingii.md
# Copied: analyticgeometryandlinearalgebraii.s22.md
# Copied: _sensors_and_sensing.md
# Copied: introductiontoartificialintelligence.s22.md
# Copied: englishforacademicpurposesi.f21.md
# Copied: _introduction_to_artificial_intelligence.s22.md
# Copied: mechanicsandmachines.md
# Copied: operatingsystems.md
# Copied: _software_systems_design.md
# Copied: fundamentalsofsoftwareengineering.md
# Copied: datamodelingdatabasesi.md
# Copied: differentialequations.f21.md
# Copied: theoreticalcomputerscience.md
# Copied: philosophyi.f21.md
# Copied: englishforacademicpurposesii.md
# Copied: _fundamentals_of_computer_security.md
# Copied: probabilityandstatistics.f21.md
# Copied: theoreticalmechanics.f21.md
# Copied: statisticaltechniquesfordatascience.md
# Copied: systemandnetworkadministration.md
# Copied: principelsofcomputersecurity.md
# Copied: _natural_language_processing.md
# Copied: signalsandsystems.s22.md
# Copied: operatingsystems%d1%8e.f21.md
# Copied: _probability_and_statistics.s22.md
# Copied: distributedandnetworkprogramming.md
# Copied: introductiontorobotics.f21.md
# Copied: advanceddatabases.md
# Copied: philosophyii.f21.md
# Copied: _physical_culture_and_sport_nutrition.md
# Copied: syllabi_table_3%2b11.md
# Copied: mechatronics.f21.md
# Copied: syllabi_table_3%2b1.md
# Copied: advancedcompilersconstructionandprogramanalysis.s22.md
# Copied: _ceo_toolkit.md
# Copied: _mste:_it_course.md
# Copied: _market_research_for_it_startups.md
# Copied: _analysis_of_software_artifacts.md
# Copied: _introduction_to_programming.md
# Copied: _it_product_development.md
# Copied: _leadership_in_entrepreneurship.md
# Copied: _it_course.md
# Copied: academicresearchandwritingculture.md
# Copied: syllabi_table.md
# Copied: founderproject.md
# Copied: itproductdevelopment.md
# Copied: ceotoolkit:strategy,operations,finance,hr,legalaspects,iplawandinnovations.md
# Copied: schedule.md
# Copied: studyplan.md

# %% [markdown]
# Turn on logging

# %%
import logging
import sys


logging.basicConfig(stream=sys.stdout, level=logging.WARNING)
logging.getLogger().addHandler(logging.StreamHandler(stream=sys.stdout))

# %% [markdown]
# ## LlamaIndex

# %%
import chromadb
from llama_index import VectorStoreIndex, SimpleDirectoryReader, ServiceContext, StorageContext, load_index_from_storage
from llama_index.storage.storage_context import StorageContext

# %% [markdown]
# ### Load documents

# %%
docs_dir = "../data/documents/raw"
documents = SimpleDirectoryReader(docs_dir).load_data()

# %%
persist_dir = "../storage"
db = chromadb.PersistentClient(path=persist_dir)

chroma_collection = db.get_or_create_collection("saira")

# %% [markdown]
# ### Create storage context

# %%
from llama_index.vector_stores import ChromaVectorStore


vector_store = ChromaVectorStore(chroma_collection=chroma_collection)

# %%
storage_context = StorageContext.from_defaults(
    vector_store=vector_store,
    )

# %%
storage_context.persist(persist_dir=persist_dir)

# %% [markdown]
# ### Create service context

# %%
from llama_index.llms import Ollama


llm_model = "llama2:13b"
# llm_model = "mistral"
# llm_model = "yarn-mistral:7b-64k"
# llm_model = "orca2:13b"
llm = Ollama(model=llm_model)

# %%
from llama_index.embeddings import HuggingFaceEmbedding


# emb_model = "Cohere/Cohere-embed-multilingual-v3.0"
# emb_model = "intfloat/multilingual-e5-large"
emb_model = "intfloat/multilingual-e5-base"
emb_model = "intfloat/multilingual-e5-small"
embed_model = HuggingFaceEmbedding(model_name=emb_model)

# %%
from llama_index.node_parser.file import SimpleFileNodeParser
# from llama_index.node_parser import SentenceSplitter


# node_parser = SimpleFileNodeParser()
# node_parser = SentenceSplitter(chunk_size=1024, chunk_overlap=20)

# %%
from llama_index import PromptHelper


# prompt_helper = PromptHelper(
    # context_window=4096,
    # num_output=256,
    # chunk_overlap_ratio=0.1,
    # chunk_size_limit=None,
# )

# %%
service_context = ServiceContext.from_defaults(
    llm=llm,
    embed_model='local',
    # node_parser=node_parser,
    # prompt_helper=prompt_helper,
    chunk_size=1024,
    chunk_overlap=20
)

# %% [markdown]
# ### Create index

# %%
index = VectorStoreIndex.from_documents(
    documents, service_context=service_context, storage_context=storage_context
)

# %%
index_load = load_index_from_storage(storage_context, service_context=service_context)

# %% [markdown]
# ### Create query engine (retriever)

# %%
query_engine = index.as_query_engine(similarity_top_k=10, response_mode="tree_summarize", streaming=False)

# %%
response = query_engine.query("What types of references do exist?")
print(response)
# Out:
# Based on the provided context information, there are two types of references that exist in academic writing: APA (American Psychological Association) and IEEE (Institute of Electrical and Electronics Engineers). These referencing styles have specific requirements for citing sources in a research paper. Additionally, there are resources available to help students avoid plagiarism, such as guidelines on paraphrasing, summarizing, quotations, and reference lists. The course covers these topics in detail, along with examples of exercises and tutorials to help students practice and improve their writing skills.

# %%
response = query_engine.query("What are innopoints?")
print(response)
# Out:
# Innopoints is a motivation and reward system designed to recognize students for their outstanding contribution to extracurricular activities at Innopolis University. Students can earn innopoints by volunteering, managing student clubs, and participating in other extracurricular events. These points can be exchanged for branded merchandise, monthly accommodation, and meals at the InnoStore. To volunteer and earn innopoints, students must log in to ipts.innopolis.university using their inno email, agree with @VOSpiridonova to create their own project, and close their event on the website after it is complete.

# %%
query_engine_2 = index.as_query_engine(streaming=True)

# %%
response = query_engine_2.query("What are innopoints?")
response.print_response_stream()
# Out:
# Innopoints are a motivation and reward system designed to encourage student participation in extracurricular activities at IU. They are awarded for various contributions such as volunteering and managing student clubs, and can be exchanged for branded merchandise, monthly accommodation and meals.

# %%
response = query_engine_2.query("How to create a student club?")
response.print_response_stream()
# Out:
# You can create a student club at campuslife.innopolis.ru/clubs by clicking on "Create my Club" button. For questions please contact @VOSpiridonova.

# %% [markdown]
# # Evaluation
